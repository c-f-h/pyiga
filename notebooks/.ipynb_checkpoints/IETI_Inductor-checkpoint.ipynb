# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy as np
import scipy
import copy

from scipy.sparse import coo_matrix, block_diag, identity, hstack, csr_matrix, csc_matrix, vstack
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import time 
from pyiga import assemble, bspline, vform, geometry, vis, solvers, utils, topology, ieti, algebra, operators, adaptive
from pyiga import algebra_cy, ieti_cy, bspline_cy

from scipy.sparse.linalg import aslinearoperator as LinOp

np.set_printoptions(linewidth=100000)
np.set_printoptions(precision=5)

# %%
def admissibility_split(MP, a, return_P=False, subspace=False, consistency = False, with_edges=False, level=None):
    marked = set()
    mapped = lambda x: 1 if x in (0, 1) else 0
    num_split=0
    assert isinstance(a,dict) and len(a)==len(MP.mesh.domains), 'Invalid type for diffusion coefficient'
    if return_P:
        P = scipy.sparse.identity(MP.nLocDofs)
    while True:
        for p in range(MP.mesh.numpatches):
            for b in range(4):
                kv = MP.mesh.kvs[p][mapped(b)]
                deg = kv.p
                s1,s2 = kv.support()
                nodes = np.clip(MP.mesh.boundaries(p)[1][b],kv.kv[0],kv.kv[-1])
                diff = nodes[1:]-nodes[:-1]
                
                if not with_edges:
                    check_edge=np.repeat(False, len(diff))
                else:
                    check_edge=((s2-s1)/diff<2**level+1e-14)
                #print(check_edge)
                if not bspline_cy.pyx_checkSWcondition(kv.kv, kv.p, len(kv.kv), nodes, len(nodes), with_edges=with_edges, check_edge=check_edge):
                    marked.add(p)
        if consistency:
            for (p1,b1) in MP.mesh.L_intfs:
                if len(MP.mesh.L_intfs[(p1,b1)])>1:
                    p2 = MP.mesh.L_intfs[(p1,b1)][0][0]
                    if a[MP.mesh.patch_domains[p1]] + 1e-3 < a[MP.mesh.patch_domains[p2]]:
                        marked.add(p1)
        if len(marked)>0:
            num_split+=len(marked)
            if return_P:
                P = MP.h_refine({p:None for p in marked}, ref="rs", return_P=return_P, in_subspace=subspace) @ P
            else:
                MP.h_refine({p:None for p in marked}, ref="rs", return_P=return_P, in_subspace=subspace)
            marked=set()
        else:
            break
    if consistency:
        print("Split {} additional patches due to admissibility and consistency".format(num_split))
    else:
        print("Split {} additional patches due to admissibility".format(num_split))
    if return_P:
        return P

# %%
def Inductor(deg,N, airgap=0.025, thin=False):
    kvs=42*[2*(bspline.make_knots(deg,0.0,1.0,N),)]
    
    geos=[      
        geometry.unit_square().scale((0.5)).translate((-0.5,-0.5)),
        geometry.unit_square().scale((0.25,0.5)).translate((0,-0.5)),
        geometry.unit_square().scale((0.25,0.5)).translate((0.25,-0.5)),
        geometry.unit_square().scale((0.5,0.5)).translate((0.5,-0.5)),
        geometry.unit_square().scale((0.25,0.5)).translate((1.,-0.5)),
        geometry.unit_square().scale((0.25,0.5)).translate((1.25,-0.5)),
        geometry.unit_square().scale(0.5).translate((1.5,-0.5)),
        
        geometry.unit_square().scale((0.5,0.25)).translate((-0.5,0)),
        geometry.unit_square().scale(0.25),
        geometry.unit_square().scale(0.25).translate((0.25,0)),
        geometry.unit_square().scale((0.5,0.25)).translate((0.5,0)),
        geometry.unit_square().scale((0.25,0.25)).translate((1.,0)),
        geometry.unit_square().scale((0.25,0.25)).translate((1.25,0)),
        geometry.unit_square().scale((0.5,0.25)).translate((1.5,0)),
        
        geometry.unit_square().scale((0.5,airgap)).translate((-0.5,0.25)),
        geometry.unit_square().scale((0.25,airgap)).translate((0,0.25)),
        geometry.unit_square().scale((0.25,airgap)).translate((0.25,0.25)),
        geometry.unit_square().scale((0.5,airgap)).translate((0.5,0.25)),
        geometry.unit_square().scale((0.25,airgap)).translate((1.,0.25)),
        geometry.unit_square().scale((0.25,airgap)).translate((1.25,0.25)),
        geometry.unit_square().scale((0.5,airgap)).translate((1.5,0.25)),
        
        geometry.unit_square().scale((0.5,0.5)).translate((-0.5,0.25+airgap)),
        geometry.unit_square().scale((0.25,0.5)).translate((0,0.25+airgap)),
        geometry.unit_square().scale((0.25,0.5)).translate((0.25,0.25+airgap)),
        geometry.unit_square().scale((0.5,0.5)).translate((0.5,0.25+airgap)),
        geometry.unit_square().scale((0.25,0.5)).translate((1.,0.25+airgap)),
        geometry.unit_square().scale((0.25,0.5)).translate((1.25,0.25+airgap)),
        geometry.unit_square().scale((0.5,0.5)).translate((1.5,0.25+airgap)),
        
        geometry.unit_square().scale((0.5,0.25)).translate((-0.5,0.75+airgap)),
        geometry.unit_square().scale((0.25,0.25)).translate((0,0.75+airgap)),
        geometry.unit_square().scale((0.25,0.25)).translate((0.25,0.75+airgap)),
        geometry.unit_square().scale((0.5,0.25)).translate((0.5,0.75+airgap)),
        geometry.unit_square().scale((0.25,0.25)).translate((1.,0.75+airgap)),
        geometry.unit_square().scale((0.25,0.25)).translate((1.25,0.75+airgap)),
        geometry.unit_square().scale((0.5,0.25)).translate((1.5,0.75+airgap)),
        
        geometry.unit_square().scale(0.5).translate((-0.5,1.0+airgap)),
        geometry.unit_square().scale((0.25,0.5)).translate((0,1.0+airgap)),
        geometry.unit_square().scale((0.25,0.5)).translate((0.25,1.0+airgap)),
        geometry.unit_square().scale((0.5,0.5)).translate((0.5,1.0+airgap)),
        geometry.unit_square().scale((0.25,0.5)).translate((1.,1.0+airgap)),
        geometry.unit_square().scale((0.25,0.5)).translate((1.25,1.0+airgap)),
        geometry.unit_square().scale(0.5).translate((1.5,1.0+airgap)),
         ]
    patches=list(zip(kvs,geos))
    M = topology.MultiPatch(patches)
    M.rename_domain(0,'Air')
    M.set_domain_id({'Fe':{8,9,10,11,12,22,24,26,29,30,31,32,33}, 'C1':{23}, 'C2':{25}})
    if not thin:
        M.h_refine({i:1 for i in range(14,21)});                                        #split airgap patches further in y-axis to make up for anisotropy 
        M.h_refine({i:1 for i in list(range(14,21))+list(range(42,49))});               #split airgap patches further in y-axis to make up for anisotropy 
    #M.h_refine({i:1 for i in list(range(14,21))+list(range(42,49))+list(range(49,63))}); #split airgap patches further in y-axis to make up for anisotropy
    return M

# %%
mu0 = 4.344*np.pi*1e-7
nu = {'C1': 1/mu0, 'C2':1/mu0, 'Fe':1/(2500*mu0), 'Air': 1/mu0}
j = {'C1': lambda x,y: 66/(0.125), 'C2':lambda x,y: -66/(0.125), 'Fe':lambda x,y: 0.0, 'Air': lambda x,y: 0.0}
MaT = {'C1': lambda x,y: (0.,0.), 'C2': lambda x,y:(0.,0.), 'Fe':lambda x,y:(0.,0.), 'Air': lambda x,y:(0.,0.)}
dir_data = {0:0}

# %%
degs = (2,3,5)
maxpatches =(100000,100000,100000)
level = (1,1,1)
#maxpatches=(1500,)
maxiter = (16,23,25)
#maxiter=(3,23,25)
R = np.zeros((32,5*len(degs)))
max_k=0
consistency = True
Prec='S'
plot=0
prim = {'v':1, 'e':1}
thin=0
eps=1e-9

for i,deg in enumerate(degs):
    eta = 1
    N = 2*deg + 1
    M = Inductor(deg,N,thin=thin)
    
    IMap = ieti.IetiMapper(M, dir_data)
    admissibility_split(IMap, return_P = False, subspace=False, consistency=consistency, a=nu, with_edges = bool(prim['e']), level=level[i]);
    #IMap.mesh.plotmesh();

    print("======================================================")
    print("deg = "+str(deg))
    k=0
    while k < maxiter[i]:
        print(k)
        print("Number of patches: {}".format(IMap.nPatches))
        if plot:
            M.plotmesh(figsize=(8,8),color={'C1':'yellow', 'C2':'yellow', 'Fe':'darkgrey', 'Air':'white'}, knots=0, bwidth=0.01, patch_idx=0)
            plt.axis('off');
            plt.axis('scaled');
            #plt.savefig('/home/wolfman/Pictures/Inductor/p'+str(deg)+'/i'+str(k)+'.pdf',bbox_inches='tight');
            #plt.close();
            plt.show()
        
        ### Solve
        if Prec=='S':
            IMap.parametersort(nu)
        A, RHS = IMap.assemble(a=nu,f=j, M=None)
        N = [A.shape[0] for A in A]

        Prim = csc_matrix((IMap.N_ofs_elim[-1],0))

        if bool(prim['v']):
            PrimV, to_be_eliminated = IMap.nodes_as_primals(dir_boundary=False)
            Prim = scipy.sparse.hstack([Prim, PrimV])
        if bool(prim['e']):
            Prim = scipy.sparse.hstack([Prim, IMap.interface_averages_as_primals(level[i])])

        print(Prim.shape)
        B, eliminated_constraints = IMap.ConstraintMatrices(eliminate=to_be_eliminated)
        SD = ieti.ScaledDirichletPreconditioner(A, B, IMap)

        nPrim=Prim.shape[1]

        R[k,i*5+3]=nPrim
        R[k,i*5+4]=IMap.nPatches

        primal = ieti.PrimalSystem(Prim)
        modA, modB, modRHS, C = primal.incorporate_PrimalConstraints(A, B, RHS, IMap)
    
        loc_solver = primal.compute_PrimalBasis(modA, modB, modRHS, C)
            
        modA.append(primal.A_prim), modB.append(primal.B_prim), modRHS.append(primal.RHS_prim)
        loc_solver.append(solvers.make_solver(primal.A_prim, spd=True, symm=True)), N.append(primal.A_prim.shape[0])
            
        I = ieti.IetiSystem(modA, modB, modRHS, N, loc_solver)
        F, b = I.SchurComplement(), I.RHSforSchurComplement()

        if Prec=='S':
            SD.setupSelectionScaling()
            P = SD.AsOperator()
        elif Prec=='D':
            SD.SchurAsMatrices()
            P=ieti.EdgePreconditioner(IMap, SD.S_dense, SD.B ,C)
        else:
            print('error')
        
        lam, it, min_eig, max_eig, r = solvers.pcg(F, b, x0=None, maxiter=2000, P=P, output=1, rtol=1e-8, atol=1e-12)
        R[k,i*5+1] = it
        R[k,i*5+2] = max_eig/min_eig

        uh = I.constructSolutionFromLagrangeMultipliers(lam)
        uh = primal.distributePrimalSolution(uh)
        uh = np.concatenate(IMap.completeDirichlet(uh))
            
        err_ind=adaptive.mp_resPois(IMap, uh, nu=nu, f=j)
        eta = np.linalg.norm(err_ind)
        #eta.append(eta)
        R[k,i*5] = eta
        #print(eta[-1]/Eerr)

        print("Error Estimator: {:.3}".format(eta))
        marked_patches = adaptive.doerfler_mark(err_ind, theta=0.8, TOL=0.01)
        marked_patches = {p:None for p in marked_patches}

        if IMap.nPatches + 3*len(marked_patches) >= maxpatches[i]:
            break;

        if eta < eps:
            break;

        if k<maxiter[i]:
            P = IMap.h_refine(h_ref=marked_patches,ref="rs", return_P = False, in_subspace=False)
    
            admissibility_split(IMap, return_P = False, subspace=False, consistency=consistency, a=nu, with_edges = bool(prim['e']), level=level[i]);

        k+=1
        print("#####################################################")

    max_k=max(k,max_k)

R=R[:max_k,:]
#np.save("Inductor_"+Prec+"_A_consistency"+str(deg),R)
if prim['e']:
    if thin:
        if consistency:
            np.save("Inductor_"+Prec+"_B_consistency_thin",R)
        else:
            np.save("Inductor_"+Prec+"_B_thin",R)
    else:
        if consistency:
            np.save("Inductor_"+Prec+"_B_consistency",R)
        else:
            np.save("Inductor_"+Prec+"_B",R)
else:
    if thin:
        if consistency:
            np.save("Inductor_"+Prec+"_A_consistency_thin",R)
        else:
            np.save("Inductor_"+Prec+"_A_thin",R)
    else:
        if consistency:
            np.save("Inductor_"+Prec+"_A_consistency",R)
        else:
            np.save("Inductor_"+Prec+"_A",R)
# Out:
# setting up constraints took 0.09631967544555664 seconds.
# setting up constraints took 0.15525245666503906 seconds.
# setting up constraints took 0.23760652542114258 seconds.
# Split 32 additional patches due to admissibility and consistency
# ======================================================
# deg = 2
# 0
# Number of patches: 159
# (7791, 502)
# pcg with preconditioned condition number κ ~ 3.274 stopped after 15 iterations with relres 4.991e-09 after 0.0943 seconds.
# Error Estimator: 1.37
# setting up constraints took 0.3137192726135254 seconds.
# setting up constraints took 0.3334996700286865 seconds.
# Split 4 additional patches due to admissibility and consistency
# #####################################################
# 1
# Number of patches: 219
# (10731, 718)
# pcg with preconditioned condition number κ ~ 3.737 stopped after 16 iterations with relres 4.392e-09 after 0.146 seconds.
# Error Estimator: 0.883
# setting up constraints took 0.41477394104003906 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 2
# Number of patches: 267
# (13083, 894)
# pcg with preconditioned condition number κ ~ 4.188 stopped after 17 iterations with relres 4.263e-09 after 0.199 seconds.
# Error Estimator: 0.544
# setting up constraints took 0.5147261619567871 seconds.
# setting up constraints took 0.5305032730102539 seconds.
# setting up constraints took 0.5337662696838379 seconds.
# Split 6 additional patches due to admissibility and consistency
# #####################################################
# 3
# Number of patches: 339
# (16611, 1146)
# pcg with preconditioned condition number κ ~ 4.28 stopped after 18 iterations with relres 3.75e-09 after 0.279 seconds.
# Error Estimator: 0.35
# setting up constraints took 0.6570088863372803 seconds.
# setting up constraints took 0.6784441471099854 seconds.
# Split 6 additional patches due to admissibility and consistency
# #####################################################
# 4
# Number of patches: 411
# (20139, 1406)
# pcg with preconditioned condition number κ ~ 4.45 stopped after 18 iterations with relres 3.931e-09 after 0.373 seconds.
# Error Estimator: 0.22
# setting up constraints took 0.7759294509887695 seconds.
# setting up constraints took 0.8227238655090332 seconds.
# setting up constraints took 0.8317146301269531 seconds.
# Split 12 additional patches due to admissibility and consistency
# #####################################################
# 5
# Number of patches: 513
# (25137, 1772)
# pcg with preconditioned condition number κ ~ 4.886 stopped after 18 iterations with relres 6.726e-09 after 0.51 seconds.
# Error Estimator: 0.141
# setting up constraints took 0.9492354393005371 seconds.
# setting up constraints took 0.992079496383667 seconds.
# Split 8 additional patches due to admissibility and consistency
# #####################################################
# 6
# Number of patches: 609
# (29841, 2124)
# pcg with preconditioned condition number κ ~ 4.555 stopped after 18 iterations with relres 5.213e-09 after 0.651 seconds.
# Error Estimator: 0.0934
# setting up constraints took 1.12184739112854 seconds.
# setting up constraints took 1.1776363849639893 seconds.
# Split 10 additional patches due to admissibility and consistency
# #####################################################
# 7
# Number of patches: 717
# (35133, 2516)
# pcg with preconditioned condition number κ ~ 4.549 stopped after 18 iterations with relres 7.24e-09 after 0.795 seconds.
# Error Estimator: 0.0591
# setting up constraints took 1.3275845050811768 seconds.
# setting up constraints took 1.3652825355529785 seconds.
# Split 8 additional patches due to admissibility and consistency
# #####################################################
# 8
# Number of patches: 825
# (40425, 2908)
# pcg with preconditioned condition number κ ~ 4.548 stopped after 18 iterations with relres 6.796e-09 after 0.971 seconds.
# Error Estimator: 0.0389
# setting up constraints took 1.5422077178955078 seconds.
# setting up constraints took 1.5691556930541992 seconds.
# Split 8 additional patches due to admissibility and consistency
# #####################################################
# 9
# Number of patches: 954
# (46746, 3361)
# pcg with preconditioned condition number κ ~ 4.543 stopped after 18 iterations with relres 6.728e-09 after 1.29 seconds.
# Error Estimator: 0.0258
# setting up constraints took 1.7552378177642822 seconds.
# setting up constraints took 1.8457276821136475 seconds.
# Split 8 additional patches due to admissibility and consistency
# #####################################################
# 10
# Number of patches: 1092
# (53508, 3861)
# pcg with preconditioned condition number κ ~ 4.552 stopped after 18 iterations with relres 6.951e-09 after 1.55 seconds.
# Error Estimator: 0.017
# setting up constraints took 2.0074431896209717 seconds.
# setting up constraints took 2.0419156551361084 seconds.
# Split 8 additional patches due to admissibility and consistency
# #####################################################
# 11
# Number of patches: 1248
# (61152, 4419)
# pcg with preconditioned condition number κ ~ 4.634 stopped after 18 iterations with relres 9.223e-09 after 2.14 seconds.
# Error Estimator: 0.0114
# setting up constraints took 2.347874641418457 seconds.
# setting up constraints took 2.405395746231079 seconds.
# Split 10 additional patches due to admissibility and consistency
# #####################################################
# 12
# Number of patches: 1440
# (70560, 5111)
# pcg with preconditioned condition number κ ~ 5.093 stopped after 19 iterations with relres 7.483e-09 after 2.74 seconds.
# Error Estimator: 0.00756
# setting up constraints took 2.746405601501465 seconds.
# setting up constraints took 2.8064873218536377 seconds.
# Split 18 additional patches due to admissibility and consistency
# #####################################################
# 13
# Number of patches: 1692
# (82908, 5995)
# pcg with preconditioned condition number κ ~ 5.095 stopped after 19 iterations with relres 7.167e-09 after 2.97 seconds.
# Error Estimator: 0.00512
# setting up constraints took 3.2222046852111816 seconds.
# setting up constraints took 3.324732542037964 seconds.
# Split 20 additional patches due to admissibility and consistency
# #####################################################
# 14
# Number of patches: 2010
# (98490, 7117)
# pcg with preconditioned condition number κ ~ 4.902 stopped after 19 iterations with relres 6.291e-09 after 3.73 seconds.
# Error Estimator: 0.00334
# setting up constraints took 3.8254387378692627 seconds.
# setting up constraints took 3.933513641357422 seconds.
# Split 14 additional patches due to admissibility and consistency
# #####################################################
# 15
# Number of patches: 2412
# (118188, 8523)
# pcg with preconditioned condition number κ ~ 5.347 stopped after 20 iterations with relres 4.549e-09 after 5.28 seconds.
# Error Estimator: 0.00217
# setting up constraints took 4.8624632358551025 seconds.
# setting up constraints took 4.920041084289551 seconds.
# setting up constraints took 4.87311863899231 seconds.
# Split 22 additional patches due to admissibility and consistency
# #####################################################
# setting up constraints took 0.09972667694091797 seconds.
# setting up constraints took 0.14020490646362305 seconds.
# setting up constraints took 0.21148371696472168 seconds.
# Split 24 additional patches due to admissibility and consistency
# ======================================================
# deg = 3
# 0
# Number of patches: 135
# (13500, 398)
# pcg with preconditioned condition number κ ~ 9.213 stopped after 21 iterations with relres 6.461e-09 after 0.152 seconds.
# Error Estimator: 1.17
# setting up constraints took 0.2742879390716553 seconds.
# setting up constraints took 0.3028252124786377 seconds.
# Split 6 additional patches due to admissibility and consistency
# #####################################################
# 1
# Number of patches: 189
# (18900, 606)
# pcg with preconditioned condition number κ ~ 9.2 stopped after 21 iterations with relres 4.191e-09 after 0.226 seconds.
# Error Estimator: 0.769
# setting up constraints took 0.3898601531982422 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 2
# Number of patches: 243
# (24300, 798)
# pcg with preconditioned condition number κ ~ 7.07 stopped after 20 iterations with relres 6.028e-09 after 0.29 seconds.
# Error Estimator: 0.48
# setting up constraints took 0.48511505126953125 seconds.
# setting up constraints took 0.49471092224121094 seconds.
# Split 2 additional patches due to admissibility and consistency
# #####################################################
# 3
# Number of patches: 303
# (30300, 1016)
# pcg with preconditioned condition number κ ~ 7.116 stopped after 20 iterations with relres 4.695e-09 after 0.454 seconds.
# Error Estimator: 0.297
# setting up constraints took 0.5941596031188965 seconds.
# setting up constraints took 0.5960931777954102 seconds.
# setting up constraints took 0.6073818206787109 seconds.
# Split 4 additional patches due to admissibility and consistency
# #####################################################
# 4
# Number of patches: 375
# (37500, 1276)
# pcg with preconditioned condition number κ ~ 4.861 stopped after 19 iterations with relres 3.773e-09 after 0.496 seconds.
# Error Estimator: 0.19
# setting up constraints took 0.7217137813568115 seconds.
# setting up constraints took 0.7518422603607178 seconds.
# Split 4 additional patches due to admissibility and consistency
# #####################################################
# 5
# Number of patches: 453
# (45300, 1560)
# pcg with preconditioned condition number κ ~ 4.861 stopped after 19 iterations with relres 3.326e-09 after 0.613 seconds.
# Error Estimator: 0.126
# setting up constraints took 0.8794119358062744 seconds.
# setting up constraints took 0.9262123107910156 seconds.
# Split 10 additional patches due to admissibility and consistency
# #####################################################
# 6
# Number of patches: 555
# (55500, 1926)
# pcg with preconditioned condition number κ ~ 5.35 stopped after 19 iterations with relres 7.886e-09 after 0.875 seconds.
# Error Estimator: 0.0823
# setting up constraints took 1.1124448776245117 seconds.
# setting up constraints took 1.078321933746338 seconds.
# Split 8 additional patches due to admissibility and consistency
# #####################################################
# 7
# Number of patches: 657
# (65700, 2296)
# pcg with preconditioned condition number κ ~ 5.193 stopped after 19 iterations with relres 9.284e-09 after 1.16 seconds.
# Error Estimator: 0.0532
# setting up constraints took 1.246096134185791 seconds.
# setting up constraints took 1.288611650466919 seconds.
# Split 8 additional patches due to admissibility and consistency
# #####################################################
# 8
# Number of patches: 765
# (76500, 2688)
# pcg with preconditioned condition number κ ~ 5.195 stopped after 20 iterations with relres 4.471e-09 after 1.42 seconds.
# Error Estimator: 0.0342
# setting up constraints took 1.5130987167358398 seconds.
# setting up constraints took 1.4894216060638428 seconds.
# Split 8 additional patches due to admissibility and consistency
# #####################################################
# 9
# Number of patches: 882
# (88200, 3107)
# pcg with preconditioned condition number κ ~ 5.202 stopped after 20 iterations with relres 4.334e-09 after 1.78 seconds.
# Error Estimator: 0.022
# setting up constraints took 1.6425678730010986 seconds.
# setting up constraints took 1.6961534023284912 seconds.
# Split 6 additional patches due to admissibility and consistency
# #####################################################
# 10
# Number of patches: 1002
# (100200, 3539)
# pcg with preconditioned condition number κ ~ 5.428 stopped after 20 iterations with relres 5.425e-09 after 2.13 seconds.
# Error Estimator: 0.0143
# setting up constraints took 1.8918755054473877 seconds.
# setting up constraints took 1.937652826309204 seconds.
# Split 10 additional patches due to admissibility and consistency
# #####################################################
# 11
# Number of patches: 1140
# (114000, 4039)
# pcg with preconditioned condition number κ ~ 5.188 stopped after 19 iterations with relres 9.179e-09 after 2.82 seconds.
# Error Estimator: 0.00923
# setting up constraints took 2.1695685386657715 seconds.
# setting up constraints took 2.209848165512085 seconds.
# Split 6 additional patches due to admissibility and consistency
# #####################################################
# 12
# Number of patches: 1278
# (127800, 4533)
# pcg with preconditioned condition number κ ~ 5.189 stopped after 19 iterations with relres 9.857e-09 after 3.19 seconds.
# Error Estimator: 0.00614
# setting up constraints took 2.3844852447509766 seconds.
# setting up constraints took 2.4185030460357666 seconds.
# Split 12 additional patches due to admissibility and consistency
# #####################################################
# 13
# Number of patches: 1440
# (144000, 5111)
# pcg with preconditioned condition number κ ~ 5.429 stopped after 20 iterations with relres 6.202e-09 after 4.13 seconds.
# Error Estimator: 0.00402
# setting up constraints took 2.6432530879974365 seconds.
# setting up constraints took 2.727949857711792 seconds.
# Split 10 additional patches due to admissibility and consistency
# #####################################################
# 14
# Number of patches: 1584
# (158400, 5639)
# pcg with preconditioned condition number κ ~ 5.427 stopped after 20 iterations with relres 6.41e-09 after 4.52 seconds.
# Error Estimator: 0.00274
# setting up constraints took 2.8899896144866943 seconds.
# setting up constraints took 2.979621648788452 seconds.
# Split 18 additional patches due to admissibility and consistency
# #####################################################
# 15
# Number of patches: 1770
# (177000, 6309)
# pcg with preconditioned condition number κ ~ 5.209 stopped after 20 iterations with relres 4.337e-09 after 4.81 seconds.
# Error Estimator: 0.00176
# setting up constraints took 3.24214768409729 seconds.
# setting up constraints took 3.308856725692749 seconds.
# setting up constraints took 3.32527232170105 seconds.
# Split 18 additional patches due to admissibility and consistency
# #####################################################
# 16
# Number of patches: 1974
# (197400, 7045)
# pcg with preconditioned condition number κ ~ 5.753 stopped after 20 iterations with relres 7.914e-09 after 5.84 seconds.
# Error Estimator: 0.00113
# setting up constraints took 3.6496315002441406 seconds.
# setting up constraints took 3.788964033126831 seconds.
# setting up constraints took 3.7299230098724365 seconds.
# Split 18 additional patches due to admissibility and consistency
# #####################################################
# 17
# Number of patches: 2196
# (219600, 7859)
# pcg with preconditioned condition number κ ~ 5.454 stopped after 20 iterations with relres 7.338e-09 after 6.71 seconds.
# Error Estimator: 0.000711
# setting up constraints took 4.028335094451904 seconds.
# setting up constraints took 4.148655891418457 seconds.
# setting up constraints took 4.10448694229126 seconds.
# Split 16 additional patches due to admissibility and consistency
# #####################################################
# 18
# Number of patches: 2406
# (240600, 8629)
# pcg with preconditioned condition number κ ~ 5.455 stopped after 20 iterations with relres 6.954e-09 after 7.94 seconds.
# Error Estimator: 0.000466
# setting up constraints took 4.37390398979187 seconds.
# setting up constraints took 4.416925668716431 seconds.
# setting up constraints took 4.430238246917725 seconds.
# Split 14 additional patches due to admissibility and consistency
# #####################################################
# 19
# Number of patches: 2628
# (262800, 9439)
# pcg with preconditioned condition number κ ~ 5.454 stopped after 20 iterations with relres 6.875e-09 after 8.79 seconds.
# Error Estimator: 0.000309
# setting up constraints took 4.885710000991821 seconds.
# setting up constraints took 4.90714955329895 seconds.
# Split 12 additional patches due to admissibility and consistency
# #####################################################
# 20
# Number of patches: 2880
# (288000, 10351)
# pcg with preconditioned condition number κ ~ 5.587 stopped after 20 iterations with relres 8.756e-09 after 11.0 seconds.
# Error Estimator: 0.000204
# setting up constraints took 5.363223314285278 seconds.
# setting up constraints took 5.4247283935546875 seconds.
# Split 10 additional patches due to admissibility and consistency
# #####################################################
# 21
# Number of patches: 3162
# (316200, 11353)
# pcg with preconditioned condition number κ ~ 5.818 stopped after 21 iterations with relres 8.054e-09 after 13.2 seconds.
# Error Estimator: 0.000133
# setting up constraints took 5.990837097167969 seconds.
# setting up constraints took 6.038093566894531 seconds.
# Split 10 additional patches due to admissibility and consistency
# #####################################################
# 22
# Number of patches: 3498
# (349800, 12533)
# pcg with preconditioned condition number κ ~ 5.822 stopped after 21 iterations with relres 7.369e-09 after 17.0 seconds.
# Error Estimator: 8.68e-05
# setting up constraints took 6.515660762786865 seconds.
# setting up constraints took 6.5111777782440186 seconds.
# Split 4 additional patches due to admissibility and consistency
# #####################################################
# setting up constraints took 0.1035299301147461 seconds.
# setting up constraints took 0.14540982246398926 seconds.
# setting up constraints took 0.2229166030883789 seconds.
# Split 24 additional patches due to admissibility and consistency
# ======================================================
# deg = 5
# 0
# Number of patches: 135
# (34560, 398)
# pcg with preconditioned condition number κ ~ 11.99 stopped after 24 iterations with relres 4.486e-09 after 0.437 seconds.
# Error Estimator: 0.794
# setting up constraints took 0.2909126281738281 seconds.
# setting up constraints took 0.32554078102111816 seconds.
# Split 6 additional patches due to admissibility and consistency
# #####################################################
# 1
# Number of patches: 189
# (48384, 606)
# pcg with preconditioned condition number κ ~ 11.96 stopped after 22 iterations with relres 8.982e-09 after 0.622 seconds.
# Error Estimator: 0.528
# setting up constraints took 0.4065268039703369 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 2
# Number of patches: 237
# (60672, 774)
# pcg with preconditioned condition number κ ~ 11.97 stopped after 23 iterations with relres 6.046e-09 after 0.787 seconds.
# Error Estimator: 0.352
# setting up constraints took 0.5144429206848145 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 3
# Number of patches: 291
# (74496, 970)
# pcg with preconditioned condition number κ ~ 11.34 stopped after 24 iterations with relres 6.046e-09 after 1.04 seconds.
# Error Estimator: 0.23
# setting up constraints took 0.6280360221862793 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 4
# Number of patches: 363
# (92928, 1224)
# pcg with preconditioned condition number κ ~ 10.51 stopped after 24 iterations with relres 5.512e-09 after 1.47 seconds.
# Error Estimator: 0.147
# setting up constraints took 0.745680570602417 seconds.
# setting up constraints took 0.7627713680267334 seconds.
# Split 2 additional patches due to admissibility and consistency
# #####################################################
# 5
# Number of patches: 441
# (112896, 1510)
# pcg with preconditioned condition number κ ~ 9.4 stopped after 23 iterations with relres 5.34e-09 after 1.71 seconds.
# Error Estimator: 0.103
# setting up constraints took 0.887775182723999 seconds.
# setting up constraints took 0.9021539688110352 seconds.
# Split 2 additional patches due to admissibility and consistency
# #####################################################
# 6
# Number of patches: 519
# (132864, 1792)
# pcg with preconditioned condition number κ ~ 9.953 stopped after 23 iterations with relres 8.345e-09 after 2.1 seconds.
# Error Estimator: 0.0728
# setting up constraints took 1.0666933059692383 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 7
# Number of patches: 603
# (154368, 2100)
# pcg with preconditioned condition number κ ~ 9.374 stopped after 23 iterations with relres 8.684e-09 after 2.53 seconds.
# Error Estimator: 0.0504
# setting up constraints took 1.2136743068695068 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 8
# Number of patches: 687
# (175872, 2398)
# pcg with preconditioned condition number κ ~ 9.58 stopped after 24 iterations with relres 4.669e-09 after 3.21 seconds.
# Error Estimator: 0.0344
# setting up constraints took 1.4006435871124268 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 9
# Number of patches: 780
# (199680, 2729)
# pcg with preconditioned condition number κ ~ 9.411 stopped after 24 iterations with relres 7.419e-09 after 3.66 seconds.
# Error Estimator: 0.0235
# setting up constraints took 1.5818583965301514 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 10
# Number of patches: 876
# (224256, 3079)
# pcg with preconditioned condition number κ ~ 9.341 stopped after 24 iterations with relres 6.266e-09 after 4.27 seconds.
# Error Estimator: 0.0169
# setting up constraints took 1.7649145126342773 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 11
# Number of patches: 990
# (253440, 3491)
# pcg with preconditioned condition number κ ~ 9.317 stopped after 25 iterations with relres 5.269e-09 after 5.06 seconds.
# Error Estimator: 0.0114
# setting up constraints took 1.9439465999603271 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 12
# Number of patches: 1116
# (285696, 3943)
# pcg with preconditioned condition number κ ~ 9.31 stopped after 25 iterations with relres 5.098e-09 after 6.11 seconds.
# Error Estimator: 0.00767
# setting up constraints took 2.24163818359375 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 13
# Number of patches: 1242
# (317952, 4393)
# pcg with preconditioned condition number κ ~ 9.432 stopped after 25 iterations with relres 6.381e-09 after 6.83 seconds.
# Error Estimator: 0.00524
# setting up constraints took 2.4448421001434326 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 14
# Number of patches: 1362
# (348672, 4835)
# pcg with preconditioned condition number κ ~ 9.429 stopped after 25 iterations with relres 6.593e-09 after 7.97 seconds.
# Error Estimator: 0.00372
# setting up constraints took 2.670637369155884 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 15
# Number of patches: 1488
# (380928, 5283)
# pcg with preconditioned condition number κ ~ 9.421 stopped after 25 iterations with relres 7.283e-09 after 8.79 seconds.
# Error Estimator: 0.00265
# setting up constraints took 2.9733545780181885 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 16
# Number of patches: 1626
# (416256, 5781)
# pcg with preconditioned condition number κ ~ 9.296 stopped after 26 iterations with relres 5.07e-09 after 10.6 seconds.
# Error Estimator: 0.00181
# setting up constraints took 3.204563617706299 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 17
# Number of patches: 1752
# (448512, 6245)
# pcg with preconditioned condition number κ ~ 9.296 stopped after 26 iterations with relres 5.447e-09 after 11.4 seconds.
# Error Estimator: 0.00132
# setting up constraints took 3.4812443256378174 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 18
# Number of patches: 1896
# (485376, 6773)
# pcg with preconditioned condition number κ ~ 9.421 stopped after 26 iterations with relres 4.949e-09 after 13.1 seconds.
# Error Estimator: 0.000924
# setting up constraints took 3.691056728363037 seconds.
# setting up constraints took 3.7858917713165283 seconds.
# Split 2 additional patches due to admissibility and consistency
# #####################################################
# 19
# Number of patches: 2034
# (520704, 7277)
# pcg with preconditioned condition number κ ~ 9.423 stopped after 25 iterations with relres 9.688e-09 after 18.5 seconds.
# Error Estimator: 0.000646
# setting up constraints took 4.021308660507202 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 20
# Number of patches: 2178
# (557568, 7795)
# pcg with preconditioned condition number κ ~ 9.343 stopped after 25 iterations with relres 7.644e-09 after 19.8 seconds.
# Error Estimator: 0.000453
# setting up constraints took 4.374873638153076 seconds.
# setting up constraints took 4.282704591751099 seconds.
# Split 2 additional patches due to admissibility and consistency
# #####################################################
# 21
# Number of patches: 2334
# (597504, 8361)
# pcg with preconditioned condition number κ ~ 9.301 stopped after 25 iterations with relres 9.166e-09 after 23.3 seconds.
# Error Estimator: 0.000306
# setting up constraints took 4.5207319259643555 seconds.
# setting up constraints took 4.599642992019653 seconds.
# Split 2 additional patches due to admissibility and consistency
# #####################################################
# 22
# Number of patches: 2490
# (637440, 8933)
# pcg with preconditioned condition number κ ~ 9.303 stopped after 25 iterations with relres 7.766e-09 after 23.3 seconds.
# Error Estimator: 0.000222
# setting up constraints took 4.8378989696502686 seconds.
# setting up constraints took 4.82949161529541 seconds.
# Split 2 additional patches due to admissibility and consistency
# #####################################################
# 23
# Number of patches: 2634
# (674304, 9459)
# pcg with preconditioned condition number κ ~ 9.428 stopped after 25 iterations with relres 9.487e-09 after 28.3 seconds.
# Error Estimator: 0.000154
# setting up constraints took 5.131553888320923 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 24
# Number of patches: 2766
# (708096, 9943)
# pcg with preconditioned condition number κ ~ 9.429 stopped after 25 iterations with relres 7.73e-09 after 28.1 seconds.
# Error Estimator: 0.000114
# setting up constraints took 5.417731761932373 seconds.
# setting up constraints took 5.386709928512573 seconds.
# Split 2 additional patches due to admissibility and consistency
# #####################################################
# 25
# Number of patches: 2916
# (746496, 10495)
# pcg with preconditioned condition number κ ~ 9.428 stopped after 25 iterations with relres 8.586e-09 after 32.4 seconds.
# Error Estimator: 7.77e-05
# setting up constraints took 5.786842107772827 seconds.
# Split 0 additional patches due to admissibility and consistency
# #####################################################
# 26
# Number of patches: 3060
# (783360, 11019)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 65
#      62 primal = ieti.PrimalSystem(Prim)
#      63 modA, modB, modRHS, C = primal.incorporate_PrimalConstraints(A, B, RHS, IMap)
# ---> 65 loc_solver = primal.compute_PrimalBasis(modA, modB, modRHS, C)
#      67 modA.append(primal.A_prim), modB.append(primal.B_prim), modRHS.append(primal.RHS_prim)
#      68 loc_solver.append(solvers.make_solver(primal.A_prim, spd=True, symm=True)), N.append(primal.A_prim.shape[0])
#
# File ~/miniforge3/pyiga/pyiga/ieti.py:344, in PrimalSystem.compute_PrimalBasis(self, mod_A, mod_B, mod_RHS, C)
#     341 psi = sol[:n_free, :]
#     342 delta = sol[n_free:, :]
# --> 344 self.Psi.append(csr_matrix(psi @ self.R[p]))
#     345 Delta.append(csr_matrix(delta))
#     347 #A_prim.append(self.R[p].T @ Delta[-1] @ self.R[p])
#
# File ~/miniforge3/lib/python3.11/site-packages/scipy/sparse/_compressed.py:92, in _cs_matrix.__init__(self, arg1, shape, dtype, copy)
#      88 if isinstance(self, sparray) and arg1.ndim < 2 and self.format == "csc":
#      89     raise ValueError(
#      90         f"CSC arrays don't support {arg1.ndim}D input. Use 2D"
#      91     )
# ---> 92 coo = self._coo_container(arg1, dtype=dtype)
#      93 arrays = coo._coo_to_compressed(self._swap)
#      94 self.indptr, self.indices, self.data, self._shape = arrays
#
# File ~/miniforge3/lib/python3.11/site-packages/scipy/sparse/_coo.py:90, in _coo_base.__init__(self, arg1, shape, dtype, copy)
#      88         raise ValueError(message)
#      89 index_dtype = self._get_index_dtype(maxval=max(self._shape))
# ---> 90 coords = M.nonzero()
#      91 self.coords = tuple(idx.astype(index_dtype, copy=False)
#      92                      for idx in coords)
#      93 self.data = M[coords]
#
# KeyboardInterrupt:

# %%
np.save("Inductor_"+Prec+"_A_"+str(deg),R)

# %%
RS = np.load('Inductor_S_A.npy')
RD = np.load('Inductor_D_A.npy')

# %%
degs=(2,3,5)

# %%
R = np.zeros((25,16))
R[:,0]=np.arange(25)
R[:,np.array([1,2,3,6,7,8,11,12,13])]=RS[:,np.array([0,1,2,5,6,7,10,11,12])]
R[:,np.array([4,5,9,10,14,15])]=RD[:,np.array([1,2,6,7,11,12])]
np.savetxt('Inductor_A', R, fmt=('%d',)+len(degs)*('%1.1e','%d','%1.1f','%d','%1.1f'), delimiter = ' & ', newline='\\\\\n')

# %%
i=0
RS[:,i]-RD[:,i]
# Out:
# array([-9.45171e-09,  1.85181e-08,  3.54351e-09,  2.53348e-08,  5.44340e-09,  6.92071e-09,  7.23139e-09, -3.33851e-09,  4.47866e-10,  1.09701e-09, -1.13456e-09,  1.63202e-09,  8.06012e-10,  1.20855e-09,  6.55818e-10,  7.52450e-10,  1.63649e-10, -2.63155e-11, -1.60371e-10,  1.70262e-10,  0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00])

# %%
SA = np.load('Inductor_S_B_consistency_thin.npy')
SB = np.load('Inductor_D_B_thin.npy')

# %%
R = np.zeros((24,19))
R[:,0]=np.arange(24)
R[:,np.array([1,2,3,7,8,9,13,14,15])]=SA[:,np.array([0,1,2,5,6,7,10,11,12])]
R[:-1,np.array([4,5,6,10,11,12,16,17,18])]=SB[:,np.array([0,1,2,5,6,7,10,11,12])]
np.savetxt('Inductor_B_consistency_thin', R, fmt=('%d',)+len(degs)*('%1.1e','%d','%1.1f','%1.1e','%d','%1.1f'), delimiter = ' & ', newline='\\\\\n')

# %%
i=0
SA[:-1,i]-SB[:,i]
# Out:
# array([ 7.11236e-11, -6.27526e-03, -1.16253e-02, -1.79461e-02, -2.65274e-02, -5.69566e-03,  1.21367e-03, -1.05729e-05, -1.58153e-05, -2.39662e-05, -3.98176e-02, -8.05302e-03, -4.96022e-03, -1.26942e-02, -4.22933e-03, -2.66429e-03, -1.49685e-03, -1.63887e-03, -8.05077e-04, -1.35590e-03,  0.00000e+00,  0.00000e+00,  0.00000e+00])

# %%
RS = np.load('Inductor_S_A_consistency.npy')
RD = np.load('Inductor_D_A.npy')

# %%
R = np.zeros((32,19))
R[:,0]=np.arange(32)

# %%
degs=(2,3,5)
maxiter = (16,27,30)
marker=('o-','^-','s-')
for i,deg in enumerate(degs):
    ndofs1 = RS[:maxiter[i],4+i*5]*(3*deg+1)**2
    ndofs2 = RD[:maxiter[i],4+i*5]*(3*deg+1)**2
    eta1=RS[:maxiter[i],5*i]
    eta2=RD[:maxiter[i],5*i]
    ndofs1=ndofs1[ndofs1!=0]
    ndofs2=ndofs2[ndofs2!=0]
    eta1=eta1[eta1!=0]
    eta2=eta2[eta2!=0]
    
    plt.loglog(ndofs1, eta1, marker[i], color='red' , label="(S): p="+str(deg),markerfacecolor='none')
    plt.loglog(ndofs2, eta2, marker[i], color='royalblue', label="p="+str(deg),markerfacecolor='none')
plt.legend(loc='lower left',prop={'size': 14})
plt.grid(True)

# %%
marker
# Out:
# '-'

# %%
eta1
# Out:
# array([7.93932e-01, 5.27845e-01, 3.52449e-01, 2.30151e-01, 1.46882e-01, 1.03085e-01, 7.28025e-02, 5.04013e-02, 3.43977e-02, 2.35359e-02, 1.68665e-02, 1.13508e-02, 7.67222e-03, 5.24123e-03, 3.72078e-03, 2.64856e-03, 1.80605e-03, 1.31502e-03, 9.23882e-04, 6.52527e-04, 4.52806e-04, 3.09562e-04, 2.32208e-04, 1.63688e-04, 1.16497e-04])

# %%
eta2
# Out:
# array([1.21595e+00, 8.73807e-01, 6.19180e-01, 3.99708e-01, 2.80648e-01, 1.79684e-01, 1.18311e-01, 8.55961e-02, 5.90562e-02, 4.08233e-02, 2.89180e-02, 2.03802e-02, 1.36899e-02, 9.43735e-03, 6.27778e-03, 4.34763e-03, 3.01821e-03, 2.13875e-03, 1.48184e-03, 1.05620e-03, 7.22995e-04, 4.68326e-04, 3.22907e-04, 2.37278e-04, 1.70144e-04])

# %%
N=2
M = topology.MultiPatch([(2*(bspline.make_knots(deg,0,1,N),),geometry.unit_square())])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 N=2
# ----> 2 M = topology.MultiPatch([(2*(bspline.make_knots(deg,0,1,N),),geometry.unit_square())])
#
# NameError: name 'deg' is not defined

# %%
deg=2
M = Inductor(deg,2*deg+1,thin=0,airgap=0.2)
mu0 = 4.344*np.pi*1e-7
nu = {'C1': 1/mu0, 'C2':1/mu0, 'Fe':1/(2500*mu0), 'Air': 1/mu0}
j = {'C1': lambda x,y: 66/(0.125), 'C2':lambda x,y: -66/(0.125), 'Fe':lambda x,y: 0.0, 'Air': lambda x,y: 0.0}

# %%
def Kellogg(deg,N):
    M = topology.MultiPatch([(2*(bspline.make_knots(deg,0,1,N),),geometry.unit_square())])
    M.h_refine();
    M.h_refine();
    M.set_domain_id({1:{3,6,8,10}})
    return M

# %%
M = Kellogg(1,2)
#nu={0:1e2,1:1.0}
j = {0:0.0,1:500.0}

# %%
E = 1
Prec='S'
IMap = ieti.IetiMapper(M, dir_data={0:0})
#admissibility_split(IMap, return_P = False, subspace=False, consistency=True, a=nu, with_edges = E);
#IMap.parametersort(nu)
A, RHS = IMap.assemble(a=1e7,f=j,M=None)
N = [A.shape[0] for A in A]
# Out:
# setting up constraints took 0.016848087310791016 seconds.

# %%
PrimV, to_be_eliminated = IMap.nodes_as_primals(dir_boundary=False)
Prim = PrimV
if E:
    PrimE = IMap.interface_averages_as_primals()
    Prim = scipy.sparse.hstack([Prim,PrimE])
print(Prim.shape)
# Out:
# (144, 33)

# %%
B, eliminated_constraints = IMap.ConstraintMatrices(eliminate=to_be_eliminated)
SD = ieti.ScaledDirichletPreconditioner(A, B, IMap)

# %%
primal = ieti.PrimalSystem(Prim)
modA, modB, modRHS, C = primal.incorporate_PrimalConstraints(A, B, RHS, IMap)

# for a in modA:
#     print(a.toarray())
    
loc_solver = primal.compute_PrimalBasis(modA, modB, modRHS, C)
            
modA.append(primal.A_prim), modB.append(primal.B_prim), modRHS.append(primal.RHS_prim)
loc_solver.append(solvers.make_solver(primal.A_prim, spd=True, symm=True)), N.append(primal.A_prim.shape[0])
            
I = ieti.IetiSystem(modA, modB, modRHS, N, loc_solver, spd=True)
F, b = I.SchurComplement(), I.RHSforSchurComplement()

# %%
if Prec=='S':
    SD.setupSelectionScaling()
    P = SD.AsOperator()
elif Prec=='D':
    SD.SchurAsMatrices()
    P=ieti.EdgePreconditioner(IMap, SD.S_dense, SD.B ,C)
lam, it, min_eig, max_eig, r = solvers.pcg(F, b, x0=None, maxiter=2000, P=1, output=1, rtol=1e-8, atol=1e-12)
# Out:
# pcg with preconditioned condition number κ ~ 1.0 stopped after 0 iterations with relres 1.0 after 0.00058 seconds.

# %%
F_full = (F@np.eye(F.shape[0]))
M_full = (P@np.eye(P.shape[0]))

# %%
eigs,_=np.linalg.eigh(F_full)
print(eigs.max(),eigs.min())
eigs,_=np.linalg.eigh(M_full)
print(eigs.max(),eigs.min())
# Out:
# 3.042570123927291e-23 -4.4141716983341156e-23
# 18015724.66785709 7400941.998809585

# %%
print(np.linalg.norm(F_full - F_full.T))
# Out:
# 1.3198613781715012e-23

# %%
A = I.A[0]

# %%
from pymklpardiso import PardisoSolver
print(A.toarray())
Ah = scipy.sparse.triu(A, format='csr')
solver = PardisoSolver(Ah,mtype=-2)
#solver = PardisoSolver(A,mtype=11)

# solver.set_iparm(7, 2)    # two iterative refinement steps
# solver.set_iparm(10, 1)   # scaling
solver.set_iparm(12, 1)   # weighted matching

solver.factor(Ah.data)
x = np.random.randn(A.shape[1])
y = solver.solve(x)

r = A @ y - x
print(np.linalg.norm(r))
# Out:
# [[ 2.66667e+07 -3.33333e+06 -3.33333e+06 -3.33333e+06  0.00000e+00]
#  [-3.33333e+06  1.33333e+07 -3.33333e+06 -1.66667e+06  0.00000e+00]
#  [-3.33333e+06 -3.33333e+06  1.33333e+07 -1.66667e+06  0.00000e+00]
#  [-3.33333e+06 -1.66667e+06 -1.66667e+06  6.66667e+06  1.00000e+00]
#  [ 0.00000e+00  0.00000e+00  0.00000e+00  1.00000e+00  0.00000e+00]]
# 6.914392812670384e-12

# %%
import pymklpardiso
print(pymklpardiso.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 2
#       1 import pymklpardiso
# ----> 2 print(pymklpardiso.__version__)
#
# AttributeError: module 'pymklpardiso' has no attribute '__version__'

# %%
operators.make_solver(I.A[0],symm=True)
# Out:
# <5x5 SolverWrapper with dtype=float64>

# %%
A = I.A[0]
x = np.random.randn(A.shape[0])

A = I.A[p].toarray()
print(np.linalg.cond(A))

for s in [1]:
    As = s * A
    Sp = PardisoSolver(As, mtype=11,msglvl=0)
    y = Sp.solve(x)
    rel = np.linalg.norm(As @ y - x) / np.linalg.norm(x)
    print(s, rel)
# Out:
# 1012.2492772503342
# 11.00000000000001
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 10
#       8 As = s * A
#       9 print(np.max(np.abs(As.data)))
# ---> 10 Sp = PardisoSolver(As, mtype=11,msglvl=0)
#      11 y = Sp.solve(x)
#      12 rel = np.linalg.norm(As @ y - x) / np.linalg.norm(x)
#
# File ~/miniforge3/lib/python3.11/site-packages/pymklpardiso/__init__.py:37, in PardisoSolver.__init__(self, A, mtype, iparms, msglvl)
#      34 if n != n_cols:
#      35     raise ValueError("A must be square")
# ---> 37 indptr = np.asarray(A.indptr, dtype=np.int64)
#      38 indices = np.asarray(A.indices, dtype=np.int64)
#      39 data = np.asarray(A.data, dtype=np.float64)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'indptr'

# %%
import importlib.metadata
print(importlib.metadata.version("pymklpardiso"))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File ~/miniforge3/lib/python3.11/importlib/metadata/__init__.py:563, in Distribution.from_name(cls, name)
#     562 try:
# --> 563     return next(cls.discover(name=name))
#     564 except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[78], line 2
#       1 import importlib.metadata
# ----> 2 print(importlib.metadata.version("pymklpardiso"))
#
# File ~/miniforge3/lib/python3.11/importlib/metadata/__init__.py:1009, in version(distribution_name)
#    1002 def version(distribution_name):
#    1003     """Get the version string for the named package.
#    1004
#    1005     :param distribution_name: The name of the distribution package to query.
#    1006     :return: The version string for the package as defined in the package's
#    1007         "Version" metadata key.
#    1008     """
# -> 1009     return distribution(distribution_name).version
#
# File ~/miniforge3/lib/python3.11/importlib/metadata/__init__.py:982, in distribution(distribution_name)
#     976 def distribution(distribution_name):
#     977     """Get the ``Distribution`` instance for the named package.
#     978
#     979     :param distribution_name: The name of the distribution package as a string.
#     980     :return: A ``Distribution`` instance (or subclass thereof).
#     981     """
# --> 982     return Distribution.from_name(distribution_name)
#
# File ~/miniforge3/lib/python3.11/importlib/metadata/__init__.py:565, in Distribution.from_name(cls, name)
#     563     return next(cls.discover(name=name))
#     564 except StopIteration:
# --> 565     raise PackageNotFoundError(name)
#
# PackageNotFoundError: No package metadata was found for pymklpardiso

# %%
I.A[0]
# Out:
# <Compressed Sparse Row sparse array of dtype 'float64'
# 	with 214 stored elements and shape (19, 19)>

# %%
A = I.A[0]
S = operators.make_solver(A)

# %%
S@A.toarray()
# Out:
# array([[ 1.00000e+00,  0.00000e+00,  0.00000e+00,  9.66063e-17,  5.36442e-17, -2.68221e-17,  0.00000e+00,  9.31751e-19,  2.68221e-17,  6.70552e-18,  5.44824e-18,  9.02385e-19,  9.23298e-17,  0.00000e+00, -1.02516e-17,  5.86853e-19, -3.41059e-17, -2.70989e-15, -2.70989e-15],
#        [ 2.19047e-18,  1.00000e+00,  0.00000e+00,  4.75933e-17, -2.41958e-17,  2.68813e-17,  0.00000e+00, -8.48278e-18, -5.19355e-18,  0.00000e+00, -7.54665e-18,  5.17751e-18, -2.40260e-17,  0.00000e+00,  3.03280e-18,  0.00000e+00,  3.03921e-15, -6.72663e-15, -1.67331e-14],
#        [-8.17695e-18,  0.00000e+00,  1.00000e+00,  1.15812e-15,  2.68222e-18, -1.43052e-17,  0.00000e+00, -1.43052e-17,  9.72306e-18,  0.00000e+00,  7.15260e-18,  2.86104e-17,  3.80249e-16,  0.00000e+00, -4.63392e-18,  0.00000e+00,  2.89979e-15,  3.87324e-15, -4.07258e-14],
#        [-1.63259e-19, -0.00000e+00, -0.00000e+00,  1.00000e+00, -4.24998e-18,  1.15115e-17, -6.85792e-18, -2.50804e-16,  6.30104e-19,  7.65393e-19, -4.82504e-17,  1.25402e-16,  5.55027e-16, -0.00000e+00,  5.00380e-18, -0.00000e+00,  1.89085e-14,  2.59813e-14, -1.14886e-13],
#        [ 4.78396e-19,  0.00000e+00,  3.62302e-22, -2.58170e-17,  1.00000e+00,  3.00869e-17,  0.00000e+00, -1.54037e-18, -5.12529e-17, -2.71714e-18, -5.40554e-18,  1.36623e-18,  5.62326e-17,  0.00000e+00,  2.35385e-17,  2.90472e-18,  3.03921e-15, -1.67331e-14, -6.72663e-15],
#        [-1.34396e-18,  0.00000e+00,  2.94665e-22,  4.09399e-16,  2.16598e-17,  1.00000e+00,  3.47845e-18, -1.51732e-18,  2.60717e-17,  0.00000e+00,  2.75288e-17,  1.10532e-17,  4.04342e-16,  0.00000e+00, -8.17553e-18,  4.30627e-18,  2.47183e-15, -2.76616e-14, -2.76616e-14],
#        [ 2.29536e-18,  0.00000e+00,  1.55920e-21,  1.29668e-16,  5.62293e-19,  5.04503e-18,  1.00000e+00, -1.24150e-17, -1.66068e-17, -2.62548e-18,  0.00000e+00,  2.12409e-18, -2.71943e-16,  0.00000e+00, -3.69669e-18, -2.21309e-18,  1.30796e-14, -1.65579e-14, -9.23081e-14],
#        [-6.23467e-19,  0.00000e+00,  1.29641e-21,  5.00208e-15, -1.61994e-18, -1.28814e-17,  2.07242e-18,  1.00000e+00,  4.58148e-18,  1.42845e-18,  2.63565e-17,  1.04589e-16,  8.68076e-16,  0.00000e+00, -2.70330e-17,  7.22655e-18,  1.08751e-14,  1.37477e-14, -1.37933e-13],
#        [-3.97523e-19,  0.00000e+00,  3.45681e-22,  3.81589e-16, -3.02774e-19, -1.86012e-17, -2.95854e-18, -1.52973e-18,  1.00000e+00,  5.82894e-17,  1.59449e-17,  6.95573e-18,  1.12566e-15,  0.00000e+00, -6.64063e-17,  2.31169e-17,  2.89979e-15, -4.07258e-14,  3.87324e-15],
#        [ 6.09049e-19,  0.00000e+00,  1.55920e-21, -2.73845e-16, -4.81493e-19,  1.08843e-17, -8.38457e-18, -5.69913e-18, -6.07771e-19,  1.00000e+00, -4.57933e-17, -4.03680e-18,  1.38316e-16,  0.00000e+00,  1.85354e-17, -2.11076e-18,  1.30796e-14, -9.23081e-14, -1.65579e-14],
#        [-1.51603e-18,  0.00000e+00, -2.30045e-21, -3.39875e-16,  2.69676e-19, -1.81862e-17,  4.24442e-17,  2.30843e-17,  1.61866e-17,  2.78438e-18,  1.00000e+00, -8.25925e-18, -3.43874e-16,  0.00000e+00, -6.67096e-18, -1.14606e-18, -1.92975e-14, -4.75080e-14, -4.75080e-14],
#        [ 1.11023e-18,  0.00000e+00,  1.79533e-21, -8.32717e-15,  6.60725e-18,  8.21348e-18,  4.14817e-18,  1.23940e-16, -7.46818e-18, -2.88109e-18,  8.11867e-18,  1.00000e+00, -1.84405e-15,  0.00000e+00,  3.55092e-17, -1.51383e-17,  1.50603e-14, -4.60155e-14, -1.29850e-13],
#        [ 6.81965e-20, -0.00000e+00,  2.25406e-21,  5.55031e-16, -6.85792e-18,  1.24912e-17, -7.82232e-18, -1.03319e-17,  9.30718e-18,  3.91881e-18, -3.64939e-17,  1.33571e-17,  1.00000e+00, -0.00000e+00, -0.00000e+00, -0.00000e+00,  1.89085e-14, -1.14886e-13,  2.59813e-14],
#        [-2.80193e-19,  0.00000e+00,  1.29641e-21,  8.69069e-16, -6.55371e-18, -9.52427e-18, -2.13307e-18, -9.03584e-18,  3.38348e-17,  8.64615e-18,  1.59446e-19,  3.26448e-17,  4.99972e-15,  1.00000e+00,  1.04298e-16,  4.00981e-17,  1.08751e-14, -1.37933e-13,  1.37477e-14],
#        [ 3.51901e-19,  0.00000e+00,  1.79533e-21, -1.84554e-15,  1.66206e-17,  2.21633e-18,  1.09022e-17,  2.36864e-17, -6.06249e-17, -1.59571e-17,  3.57302e-17, -6.19639e-17, -8.32265e-15,  0.00000e+00,  1.00000e+00, -6.73645e-17,  1.50603e-14, -1.29850e-13, -4.60155e-14],
#        [-1.00952e-22, -0.00000e+00, -1.19287e-20, -9.19207e-19, -5.40092e-23, -8.28925e-21, -3.67450e-21,  4.04896e-20,  9.49542e-21, -1.61387e-21, -2.38630e-20,  1.65411e-21, -9.19898e-19, -0.00000e+00,  1.33602e-21,  1.00000e+00, -1.00065e-13,  5.53034e-17,  5.53034e-17],
#        [ 1.00952e-09,  0.00000e+00,  1.19287e-07,  9.19207e-06,  5.40092e-10,  8.28925e-08,  3.67450e-08, -4.04896e-07, -9.49542e-08,  1.61387e-08,  2.38630e-07, -1.65411e-08,  9.19898e-06,  0.00000e+00, -1.33602e-08,  0.00000e+00,  1.00065e+00, -5.53034e-04, -5.53034e-04],
#        [ 5.38823e-10,  0.00000e+00, -6.59268e-11, -2.80856e-05,  1.50948e-07, -9.26671e-07,  2.70156e-07,  3.97705e-07,  1.24615e-06, -2.06697e-06,  1.19220e-06, -8.02621e-07,  0.00000e+00,  0.00000e+00,  0.00000e+00,  0.00000e+00, -5.53034e-04,  1.00357e+00, -1.36664e-03],
#        [-2.60443e-08,  0.00000e+00,  4.94311e-09,  0.00000e+00,  1.61475e-07, -8.86092e-07, -8.82311e-07,  5.55112e-04, -8.64229e-08, -5.81796e-08,  1.35294e-06,  0.00000e+00, -2.80764e-05,  0.00000e+00,  7.96438e-08,  0.00000e+00, -5.53034e-04, -1.36664e-03,  1.00357e+00]])

# %%
print(np.linalg.matrix_rank(Psi.toarray()))
# Out:
# 14

# %%
M.plotmesh(color={'C1':'yellow', 'C2':'yellow', 'Fe':'darkgrey', 'Air':'white'}, patch_idx=1)

# %%
j['Air'](0.0,0.0)
# Out:
# 0.0

# %%
kvs = 2*(bspline.make_knots(2,0,1,50),)
M =topology.MultiPatch([(kvs,geometry.unit_square())])

# %%
M.h_refine({0:0});
M.set_domain_id({1:{1}});
M.h_refine({0:None});
M.h_refine({3:None});
#M.h_refine({2:1});
#M.h_refine({0:0});

# %%
Prec='D'
prim={'v':1,'e':0}
level=0
nu={0:1.0,1:1000.0}

IMap = ieti.IetiMapper(M, {0:0})
A, RHS = IMap.assemble(a=nu,f=1, M=None)
N = [A.shape[0] for A in A]

Prim = csc_matrix((IMap.N_ofs_elim[-1],0))

if bool(prim['v']):
    PrimV, to_be_eliminated = IMap.nodes_as_primals(dir_boundary=False)
    Prim = scipy.sparse.hstack([Prim, PrimV])
if bool(prim['e']):
    Prim = scipy.sparse.hstack([Prim, IMap.interface_averages_as_primals(level)])

    print(Prim.shape)
    B, eliminated_constraints = IMap.ConstraintMatrices(eliminate=to_be_eliminated)
    SD = ieti.ScaledDirichletPreconditioner(A, B, IMap)

    nPrim=Prim.shape[1]

    primal = ieti.PrimalSystem(Prim)
    modA, modB, modRHS, C = primal.incorporate_PrimalConstraints(A, B, RHS, IMap)

    loc_solver = primal.compute_PrimalBasis(modA, modB, modRHS, C)
        
    modA.append(primal.A_prim), modB.append(primal.B_prim), modRHS.append(primal.RHS_prim)
    loc_solver.append(solvers.make_solver(primal.A_prim, spd=True, symm=True)), N.append(primal.A_prim.shape[0])
        
    I = ieti.IetiSystem(modA, modB, modRHS, N, loc_solver)
    F, b = I.SchurComplement(), I.RHSforSchurComplement()

    if Prec=='S':
        SD.setupSelectionScaling()
        P = SD.AsOperator()
    elif Prec=='D':
        SD.SchurAsMatrices()
        P=ieti.EdgePreconditioner(IMap, SD.S_dense, SD.B ,C)
    else:
        print('error')
    
    lam, it, min_eig, max_eig, r = solvers.pcg(F, b, x0=None, maxiter=2000, P=P, output=1, rtol=1e-8, atol=1e-12)
# Out:
# setting up constraints took 0.011842727661132812 seconds.

# %%
print(Prim[:,0])
# Out:
# <Compressed Sparse Column sparse matrix of dtype 'float64'
# 	with 5 stored elements and shape (196, 1)>
#   Coords	Values
#   (48, 0)	1.0
#   (50, 0)	0.28125000000000006
#   (51, 0)	0.6875
#   (52, 0)	0.031249999999999983
#   (189, 0)	1.0

# %%
kv = bspline.make_knots(2,0,1,5)
nodes=np.array([0,0.25,0.5,1])
bspline_cy.pyx_checkSWcondition(kv.kv, kv.p, len(kv.kv), nodes, len(nodes), with_edges=True)
# Out:
# True

# %%
nodes=np.array([0,0.125,0.25,0.5,1])
diff = nodes[1:]-nodes[:-1]
level=1

# %%
1/diff<2**level+1e-14
# Out:
# array([False, False, False,  True])

# %%
1/diff
# Out:
# array([8., 8., 4., 2.])

# %%
nodes
# Out:
# array([0.   , 0.125, 0.25 , 0.5  , 1.   ])
