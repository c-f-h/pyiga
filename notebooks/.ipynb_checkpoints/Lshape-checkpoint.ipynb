# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import pyiga

import scipy
import numpy as np
import matplotlib.pyplot as plt

from scipy.sparse import csc_matrix, csr_matrix, coo_matrix
from scipy.sparse.linalg import aslinearoperator

np.set_printoptions(linewidth=100000)
np.set_printoptions(precision=5)

from pyiga import adaptive, operators, bspline, assemble, vform, geometry, vis, solvers, topology, bspline_cy
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def Lshape(deg, N):
    kvs = [2 * (bspline.make_knots(deg, 0.0, 1.0, N),),2 * (bspline.make_knots(deg, 0.0, 1.0, N),)]

    # define geometry
    geos = [
        geometry.Quad(np.array([[-1,-1],[0,-1],[-1,1],[0,0]]).T),
        geometry.Quad(np.array([[-1,1],[0,0],[1,1],[1,0]]).T)
    ]

    patches = [(k, g) for k, g in zip(kvs,geos)]
    M = topology.MultiPatch(patches)
    return M

# %%
def cart2pol(x, y):
    r = np.sqrt(x**2 + y**2)
    phi = np.arctan2(y, x)
    return(r, phi%(2*np.pi))
def u(x,y):
    r, phi = cart2pol(x,y)
    return r**(2/3)*np.sin(2*phi/3)

# %%
f = lambda x,y: 1.0
maxiter=40
deg, N = 5,5

M = Lshape(deg,N)
MP = assemble.MultiBasis(M, subspace='C0')

for i in range(maxiter):
    #M.plotmesh(knots=False)
    #plt.axis('off');
    #plt.savefig('/home/wolfman/Pictures/Lshape/i'+str(i)+'.pdf' ,bbox_inches='tight');
    #plt.show()

    bcs = MP.set_fixed_boundary({0:0.0})
    Ah = MP.assemble_volume('inner(grad(u),grad(v)) * dx', arity=2) 
    Fh = MP.assemble_volume('f * v * dx', arity=1, f=f, physical=True)
    RS = assemble.RestrictedLinearSystem(Ah,Fh,bcs)
    uh = RS.complete(operators.make_solver(RS.A,spd=True)@RS.b)

    ax = MP.plot(uh, mesh=True);
    ax.axis('off');
    plt.savefig('/home/wolfman/Pictures/Lshape/i'+str(i)+'.png' ,bbox_inches='tight', dpi=350);
    #plt.show()

    err_ind=adaptive.mp_resPois(MP,uh,f={0:f})
    marked_patches = adaptive.doerfler_mark(err_ind, theta=0.9, TOL=0)
    marked_patches = {p:None for p in marked_patches}
    MP.h_refine(h_ref=marked_patches, return_P=False)
# Out:
# setting up constraints took 0.001542806625366211 seconds.
# 10 0 0
# 0 0 0
# Basis setup took 0.003980159759521484 seconds
# setting up constraints took 0.0069713592529296875 seconds.
# 60 0 0
# 2 0 0
# 0 0 0
# Basis setup took 0.0018877983093261719 seconds
# setting up constraints took 0.011503934860229492 seconds.
# 100 0 0
# 2 0 0
# 0 0 0
# Basis setup took 0.001897573471069336 seconds
# setting up constraints took 0.02021622657775879 seconds.
# 170 0 0
# 2 0 0
# 0 0 0
# Basis setup took 0.0021224021911621094 seconds
# setting up constraints took 0.027222633361816406 seconds.
# 230 0 0
# 8 0 0
# 0 0 0
# Basis setup took 0.002189159393310547 seconds
# setting up constraints took 0.03572535514831543 seconds.
# 300 0 0
# 10 0 0
# 0 0 0
# Basis setup took 0.0022928714752197266 seconds
# setting up constraints took 0.040959835052490234 seconds.
# 360 0 0
# 8 0 0
# 0 0 0
# Basis setup took 0.002391338348388672 seconds
# setting up constraints took 0.05098581314086914 seconds.
# 430 0 0
# 10 0 0
# 0 0 0
# Basis setup took 0.0025343894958496094 seconds
# setting up constraints took 0.05468177795410156 seconds.
# 490 0 0
# 16 0 0
# 0 0 0
# Basis setup took 0.002434968948364258 seconds
# setting up constraints took 0.06419563293457031 seconds.
# 560 0 0
# 17 0 0
# 0 0 0
# Basis setup took 0.002557516098022461 seconds
# setting up constraints took 0.09681463241577148 seconds.
# 620 0 0
# 18 0 0
# 0 0 0
# Basis setup took 0.0036721229553222656 seconds
# setting up constraints took 0.07850360870361328 seconds.
# 690 0 0
# 17 0 0
# 0 0 0
# Basis setup took 0.002656698226928711 seconds
# setting up constraints took 0.09336280822753906 seconds.
# 750 0 0
# 21 0 0
# 0 0 0
# Basis setup took 0.0034067630767822266 seconds
# setting up constraints took 0.09062314033508301 seconds.
# 820 0 0
# 20 0 0
# 0 0 0
# Basis setup took 0.0027229785919189453 seconds
# setting up constraints took 0.10001826286315918 seconds.
# 880 0 0
# 25 0 0
# 0 0 0
# Basis setup took 0.0028998851776123047 seconds
# setting up constraints took 0.10709404945373535 seconds.
# 950 0 0
# 25 0 0
# 0 0 0
# Basis setup took 0.0031616687774658203 seconds
# setting up constraints took 0.11365509033203125 seconds.
# 1010 0 0
# 25 0 0
# 0 0 0
# Basis setup took 0.0031588077545166016 seconds
# setting up constraints took 0.12706732749938965 seconds.
# 1080 0 0
# 29 0 0
# 0 0 0
# Basis setup took 0.0032341480255126953 seconds
# setting up constraints took 0.13616037368774414 seconds.
# 1140 0 0
# 32 0 0
# 0 0 0
# Basis setup took 0.0034093856811523438 seconds
# setting up constraints took 0.14681553840637207 seconds.
# 1210 0 0
# 33 0 0
# 0 0 0
# Basis setup took 0.003481149673461914 seconds
# setting up constraints took 0.14404749870300293 seconds.
# 1270 0 0
# 32 0 0
# 0 0 0
# Basis setup took 0.003369569778442383 seconds
# setting up constraints took 0.1598219871520996 seconds.
# 1340 0 0
# 36 0 0
# 0 0 0
# Basis setup took 0.003509521484375 seconds
# setting up constraints took 0.17333650588989258 seconds.
# 1470 0 0
# 37 0 0
# 0 0 0
# Basis setup took 0.0037293434143066406 seconds
# setting up constraints took 0.206892728805542 seconds.
# 1710 0 0
# 43 0 0
# 0 0 0
# Basis setup took 0.003820657730102539 seconds
# setting up constraints took 0.21195173263549805 seconds.
# 1890 0 0
# 46 0 0
# 0 0 0
# Basis setup took 0.004058361053466797 seconds
# setting up constraints took 0.24758434295654297 seconds.
# 2110 0 0
# 48 0 0
# 0 0 0
# Basis setup took 0.004178524017333984 seconds
# setting up constraints took 0.2776296138763428 seconds.
# 2410 0 0
# 60 0 0
# 1 0 0
# 0 0 0
# Basis setup took 0.005192756652832031 seconds
# setting up constraints took 0.3723580837249756 seconds.
# 2720 0 0
# 69 0 0
# 0 0 0
# Basis setup took 0.004765987396240234 seconds
# setting up constraints took 0.3569061756134033 seconds.
# 3220 0 0
# 82 0 0
# 0 0 0
# Basis setup took 0.005183696746826172 seconds
# setting up constraints took 0.5031788349151611 seconds.
# 3770 0 0
# 97 0 0
# 1 0 0
# 0 0 0
# Basis setup took 0.007103681564331055 seconds
# setting up constraints took 0.5550761222839355 seconds.
# 4200 0 0
# 118 0 0
# 1 0 0
# 0 0 0
# Basis setup took 0.0066814422607421875 seconds
# setting up constraints took 0.5989155769348145 seconds.
# 4700 0 0
# 132 0 0
# 1 0 0
# 0 0 0
# Basis setup took 0.007740497589111328 seconds
# setting up constraints took 0.7035567760467529 seconds.
# 5320 0 0
# 154 0 0
# 2 0 0
# 0 0 0
# Basis setup took 0.012098312377929688 seconds
# setting up constraints took 0.7308506965637207 seconds.
# 6100 0 0
# 162 0 0
# 2 0 0
# 0 0 0
# Basis setup took 0.009323835372924805 seconds
# setting up constraints took 0.8075919151306152 seconds.
# 6840 0 0
# 171 0 0
# 2 0 0
# 0 0 0
# Basis setup took 0.009668111801147461 seconds
# setting up constraints took 0.929795503616333 seconds.
# 7850 0 0
# 206 0 0
# 3 0 0
# 0 0 0
# Basis setup took 0.01078939437866211 seconds
# setting up constraints took 1.0328807830810547 seconds.
# 9200 0 0
# 251 0 0
# 3 0 0
# 0 0 0
# Basis setup took 0.012614965438842773 seconds
# setting up constraints took 1.2313871383666992 seconds.
# 10570 0 0
# 347 0 0
# 5 0 0
# 0 0 0
# Basis setup took 0.013280868530273438 seconds
# setting up constraints took 1.3995404243469238 seconds.
# 12010 0 0
# 412 0 0
# 6 0 0
# 0 0 0
# Basis setup took 0.01564311981201172 seconds
# setting up constraints took 1.5748836994171143 seconds.
# 13600 0 0
# 451 0 0
# 8 0 0
# 0 0 0
# Basis setup took 0.024479389190673828 seconds
# setting up constraints took 1.98612380027771 seconds.
# 16110 0 0
# 556 0 0
# 11 0 0
# 0 0 0
# Basis setup took 0.030929088592529297 seconds
