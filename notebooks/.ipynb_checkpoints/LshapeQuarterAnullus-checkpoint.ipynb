# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy as np
import scipy
import copy

from scipy.sparse import coo_matrix, block_diag, identity, hstack, csr_matrix, csc_matrix, vstack
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import time 

from pyiga import assemble, bspline, vform, geometry, vis, solvers, utils, topology, ieti, algebra, operators, adaptive
from pyiga import algebra_cy, ieti_cy, bspline_cy

from scipy.sparse.linalg import aslinearoperator as LinOp

np.set_printoptions(linewidth=100000)
np.set_printoptions(precision=5)

# %%
def Lshape(deg, N, k=1):
    kvs = [2 * (bspline.make_knots(deg, 0.0, 1.0, N, mult=k),),2 * (bspline.make_knots(deg, 0.0, 1.0, N, mult=k),)]

    # define geometry
    geos = [
        geometry.Quad(np.array([[-1,-1],[0,-1],[-1,1],[0,0]]).T),
        geometry.Quad(np.array([[-1,1],[0,0],[1,1],[1,0]]).T)
    ]

    patches = [(k, g) for k, g in zip(kvs,geos)]
    M = topology.MultiPatch(patches)
    return M

# %%
def LshapeAnullus(deg, N, k=1):
    kvs = 3*[2 * (bspline.make_knots(deg, 0.0, 1.0, N, mult=k),)]

    # define geometry
    geos = [
        geometry.annulus(r1=1.5, r2=2, phi = np.pi/4),
        geometry.annulus(r1=1.5, r2=2, phi = np.pi/4).rotate_2d(angle=np.pi/4),
        geometry.annulus(r1=1.0, r2=1.5, phi = np.pi/4).rotate_2d(angle=np.pi/4),
    ]

    patches = [(k, g) for k, g in zip(kvs,geos)]
    M = topology.MultiPatch(patches)
    M.outer_boundaries[0].add((1,(0,0)))
    return M

# %%
def cart2pol(x, y):
    r = np.sqrt(x**2 + y**2)
    phi = np.arctan2(y, x)
    return(r, phi%(2*np.pi))
def u(x,y):
    r, phi = cart2pol(x,y)
    return r**(2/3)*np.sin(2*phi/3)
def ux(x,y):
    r, phi = cart2pol(x,y)
    return -2./3*r**(-1./3)*np.sin(phi/3)
def uy(x,y):
    r, phi = cart2pol(x,y)
    return 2./3*r**(-1./3)*np.cos(phi/3)

# %%
degs = (2,3,5,8)
maxpatches =(20000,15000,15000,12000)
level = (2,2,2,2)
maxiter=(15,23,28,31)
eps=1e-7
maxN=0

direct=False

prim = {'v':1, 'e':1}
R = np.zeros((50,5*len(degs)))

example=1

f=1
g=0

plot=0
dir_data={0:g}
U=[]
eta=[]

for i,deg in enumerate(degs):
    N = deg+1
    M = LshapeAnullus(deg,N,1)

    IMap = ieti.IetiMapper(M, dir_data=dir_data, elim=0)
    eta=1.0
    k=0
    while k<maxiter[i]:
        if plot:
            M.plotmesh(figsize=(10,10), knots=1, nodes=50, bwidth=0.01, patch_idx=0)
            plt.axis('off');
            plt.axis('scaled');
            plt.savefig('/home/wolfman/Pictures/p'+str(deg)+'i'+str(k)+'.png',dpi=100,bbox_inches='tight');
            plt.show();
            plt.close();

        ### SOLVE
        A, RHS = IMap.assemble(a=1,f=f, M=None)
        N = [A.shape[0] for A in A]
            
        Prim = csc_matrix((IMap.N_ofs_elim[-1],0))

        if bool(prim['v']):
            PrimV, to_be_eliminated = IMap.nodes_as_primals(dir_boundary=False)
            Prim = scipy.sparse.hstack([Prim, PrimV])
        if bool(prim['e']):
            Prim = scipy.sparse.hstack([Prim, IMap.interface_averages_as_primals(1)])

        B, eliminated_constraints = IMap.ConstraintMatrices(eliminate=to_be_eliminated)
        SD = ieti.ScaledDirichletPreconditioner(A, B, IMap)

        nPrim=Prim.shape[1]

        R[k,i*5+3]=nPrim
        R[k,i*5+4]=IMap.nPatches

        if nPrim==0:
            I = ieti.IetiSystem(A, B, RHS, N)
            F, b = I.SchurComplement(), I.RHSforSchurComplement()
            C = [scipy.sparse.csr_matrix((0,A[p].shape[1])) for p in range(len(B))]
        else:
            primal = ieti.PrimalSystem(Prim)
            modA, modB, modRHS, C = primal.incorporate_PrimalConstraints(A, B, RHS, IMap)
    
            loc_solver = primal.compute_PrimalBasis(modA, modB, modRHS, C)
            
            modA.append(primal.A_prim), modB.append(primal.B_prim), modRHS.append(primal.RHS_prim)
            loc_solver.append(solvers.make_solver(primal.A_prim, spd=True, symm=True)), N.append(primal.A_prim.shape[0])
            
            I = ieti.IetiSystem(modA, modB, modRHS, N, loc_solver)
            F, b = I.SchurComplement(), I.RHSforSchurComplement()

        SD.setupSelectionScaling()
        #SD.SchurAsMatrices()
        #SD.setupConstraintScaling()
        
        Prec = SD.AsOperator()
        #Prec=ieti.EdgePreconditioner(IMap, SD.S_dense, SD.B ,C)#@np.eye(F.shape[0])
        
        lam, it, min_eig, max_eig, r = solvers.pcg(F, b, x0=None, maxiter=2000, P=Prec, output=1, rtol=1e-8, atol=1e-12)
        R[k,i*5+1] = it
        R[k,i*5+2] = max_eig/min_eig

        uh = I.constructSolutionFromLagrangeMultipliers(lam)
        if nPrim>0:
            uh = primal.distributePrimalSolution(uh)
        uh = np.concatenate(IMap.completeDirichlet(uh))
        if IMap.elim:
            uh = IMap.Basis_loc_global@uh

        # U.append(u)

        # dir_bcs = IMap.set_fixed_boundary(dir_data, local=False)
        # Mh = IMap.assemble_volume("u * v * dx", arity=2, domain_id=0)
        # Kh = IMap.assemble_volume("inner(grad(u),grad(v)) * dx", arity=2, domain_id=0)
        # Fh = IMap.assemble_volume("(f * v) * dx", arity=1, domain_id=0, f=f)
        # LS = assemble.RestrictedLinearSystem(Kh, Fh, dir_bcs)
        # uh = LS.complete(solvers.make_solver(LS.A, spd=True)@LS.b)

        # u_load = IMap.assemble_volume("(f * v) * dx", arity=1, domain_id=0, f=u)
        # u_exact = operators.make_solver(Mh,spd=True)@u_load
        # eh = u_exact-uh
        # U.append(uh)

        # L2err = np.sqrt(eh.T@Mh@eh)
        # Eerr = np.sqrt(eh.T@Kh@eh)

        # if plot:
        #     IMap.plot(uh,mesh=True)
        #     plt.show()

        err_ind=adaptive.mp_resPois(IMap, uh, nu=1, f=f)
        eta = np.linalg.norm(err_ind)
        #eta.append(eta)
        R[k,i*5] = eta
        #print(eta[-1]/Eerr)

        print("Error Estimator: {:.3}".format(eta))
        marked_patches = adaptive.doerfler_mark(err_ind, theta=0.8, TOL=0.01)
        marked_patches = {p:None for p in marked_patches}

        if IMap.nPatches + 3*len(marked_patches) >= maxpatches[i]:
            break;

        if eta < eps:
            break;

        P = IMap.h_refine(h_ref=marked_patches,ref="rs", return_P = True, in_subspace=True)
        # for m in range(len(U)):
        #     U[m] = P@U[m]

        k+=1
        print("#####################################################")

    maxN = max(maxN,k)
R=R[:maxN,:]
np.save("LshapeQ_S_B",R)
# Out:
# setting up constraints took 0.0016319751739501953 seconds.
# pcg with preconditioned condition number κ ~ 1.176 stopped after 4 iterations with relres 5.736e-16 after 0.0183 seconds.
# Error Estimator: 0.182
# setting up constraints took 0.011304140090942383 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 2.454 stopped after 11 iterations with relres 1.591e-09 after 0.0252 seconds.
# Error Estimator: 0.0989
# setting up constraints took 0.02841043472290039 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 2.669 stopped after 12 iterations with relres 9.983e-09 after 0.0412 seconds.
# Error Estimator: 0.0615
# setting up constraints took 0.054514169692993164 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 2.666 stopped after 13 iterations with relres 4.118e-09 after 0.0655 seconds.
# Error Estimator: 0.0407
# setting up constraints took 0.07290005683898926 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 2.832 stopped after 13 iterations with relres 9.687e-09 after 0.0979 seconds.
# Error Estimator: 0.0248
# setting up constraints took 0.10008406639099121 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 2.871 stopped after 14 iterations with relres 2.678e-09 after 0.157 seconds.
# Error Estimator: 0.0167
# setting up constraints took 0.14120054244995117 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 2.944 stopped after 14 iterations with relres 4.069e-09 after 0.589 seconds.
# Error Estimator: 0.0109
# setting up constraints took 0.19276070594787598 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 2.996 stopped after 14 iterations with relres 6.238e-09 after 0.325 seconds.
# Error Estimator: 0.00711
# setting up constraints took 0.2544541358947754 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.018 stopped after 14 iterations with relres 5.232e-09 after 0.493 seconds.
# Error Estimator: 0.00456
# setting up constraints took 0.37652111053466797 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.153 stopped after 15 iterations with relres 2.569e-09 after 0.693 seconds.
# Error Estimator: 0.00292
# setting up constraints took 0.551997184753418 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.306 stopped after 15 iterations with relres 3.36e-09 after 1.05 seconds.
# Error Estimator: 0.00184
# setting up constraints took 0.8273077011108398 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.318 stopped after 15 iterations with relres 4.21e-09 after 1.75 seconds.
# Error Estimator: 0.00117
# setting up constraints took 1.2485756874084473 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.289 stopped after 15 iterations with relres 3.707e-09 after 2.66 seconds.
# Error Estimator: 0.00074
# setting up constraints took 2.011481523513794 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.361 stopped after 15 iterations with relres 4.863e-09 after 4.53 seconds.
# Error Estimator: 0.000468
# setting up constraints took 3.084066390991211 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.393 stopped after 15 iterations with relres 5.27e-09 after 12.1 seconds.
# Error Estimator: 0.000296
# setting up constraints took 4.77417254447937 seconds.
# #####################################################
# setting up constraints took 0.001542806625366211 seconds.
# pcg with preconditioned condition number κ ~ 1.416 stopped after 5 iterations with relres 5.718e-10 after 0.0328 seconds.
# Error Estimator: 0.134
# setting up constraints took 0.011881113052368164 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.003 stopped after 13 iterations with relres 3.975e-09 after 0.115 seconds.
# Error Estimator: 0.0731
# setting up constraints took 0.029412269592285156 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.406 stopped after 14 iterations with relres 8.851e-09 after 0.0842 seconds.
# Error Estimator: 0.0466
# setting up constraints took 0.042960405349731445 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.407 stopped after 15 iterations with relres 2.816e-09 after 0.0675 seconds.
# Error Estimator: 0.0302
# setting up constraints took 0.05512595176696777 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.403 stopped after 15 iterations with relres 3.033e-09 after 0.0892 seconds.
# Error Estimator: 0.0201
# setting up constraints took 0.06761026382446289 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.402 stopped after 15 iterations with relres 3.233e-09 after 0.122 seconds.
# Error Estimator: 0.0142
# setting up constraints took 0.0928347110748291 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.409 stopped after 15 iterations with relres 4.606e-09 after 0.152 seconds.
# Error Estimator: 0.00877
# setting up constraints took 0.11303520202636719 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.46 stopped after 15 iterations with relres 6.119e-09 after 0.194 seconds.
# Error Estimator: 0.00573
# setting up constraints took 0.12914085388183594 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.458 stopped after 15 iterations with relres 6.87e-09 after 0.223 seconds.
# Error Estimator: 0.00359
# setting up constraints took 0.15963506698608398 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.457 stopped after 15 iterations with relres 7.373e-09 after 0.272 seconds.
# Error Estimator: 0.00226
# setting up constraints took 0.20233893394470215 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.431 stopped after 15 iterations with relres 7.547e-09 after 0.318 seconds.
# Error Estimator: 0.00154
# setting up constraints took 0.21141958236694336 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.384 stopped after 15 iterations with relres 7.439e-09 after 0.373 seconds.
# Error Estimator: 0.000967
# setting up constraints took 0.24451947212219238 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.583 stopped after 16 iterations with relres 3.985e-09 after 0.47 seconds.
# Error Estimator: 0.000617
# setting up constraints took 0.28943777084350586 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.783 stopped after 16 iterations with relres 5.289e-09 after 0.746 seconds.
# Error Estimator: 0.000397
# setting up constraints took 0.3429543972015381 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.666 stopped after 16 iterations with relres 5.083e-09 after 0.813 seconds.
# Error Estimator: 0.000244
# setting up constraints took 0.39222025871276855 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.693 stopped after 16 iterations with relres 5.544e-09 after 0.839 seconds.
# Error Estimator: 0.000156
# setting up constraints took 0.47309041023254395 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.852 stopped after 16 iterations with relres 6.31e-09 after 1.04 seconds.
# Error Estimator: 9.98e-05
# setting up constraints took 0.5872578620910645 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 3.814 stopped after 16 iterations with relres 7.378e-09 after 1.26 seconds.
# Error Estimator: 6.33e-05
# setting up constraints took 0.7336483001708984 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.04 stopped after 16 iterations with relres 9.784e-09 after 1.78 seconds.
# Error Estimator: 3.97e-05
# setting up constraints took 0.8904190063476562 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.031 stopped after 16 iterations with relres 9.526e-09 after 2.69 seconds.
# Error Estimator: 2.51e-05
# setting up constraints took 1.1741595268249512 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.102 stopped after 16 iterations with relres 9.047e-09 after 3.02 seconds.
# Error Estimator: 1.59e-05
# setting up constraints took 1.5659096240997314 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.05 stopped after 17 iterations with relres 4.035e-09 after 7.6 seconds.
# Error Estimator: 9.92e-06
# setting up constraints took 1.9881587028503418 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.121 stopped after 17 iterations with relres 3.996e-09 after 8.78 seconds.
# Error Estimator: 6.3e-06
# setting up constraints took 2.5673344135284424 seconds.
# #####################################################
# setting up constraints took 0.0016863346099853516 seconds.
# pcg with preconditioned condition number κ ~ 1.881 stopped after 6 iterations with relres 7.056e-10 after 0.0159 seconds.
# Error Estimator: 0.124
# setting up constraints took 0.012072563171386719 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.116 stopped after 15 iterations with relres 2.463e-09 after 0.036 seconds.
# Error Estimator: 0.0682
# setting up constraints took 0.029735565185546875 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.613 stopped after 17 iterations with relres 5.367e-09 after 0.11 seconds.
# Error Estimator: 0.043
# setting up constraints took 0.04496645927429199 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.608 stopped after 17 iterations with relres 6.286e-09 after 0.175 seconds.
# Error Estimator: 0.0272
# setting up constraints took 0.057358741760253906 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.601 stopped after 17 iterations with relres 5.274e-09 after 0.167 seconds.
# Error Estimator: 0.0172
# setting up constraints took 0.07108235359191895 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.597 stopped after 17 iterations with relres 5.809e-09 after 0.235 seconds.
# Error Estimator: 0.0109
# setting up constraints took 0.08516526222229004 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.596 stopped after 17 iterations with relres 5.695e-09 after 0.257 seconds.
# Error Estimator: 0.00699
# setting up constraints took 0.1007835865020752 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.595 stopped after 17 iterations with relres 5.674e-09 after 0.312 seconds.
# Error Estimator: 0.0046
# setting up constraints took 0.1240091323852539 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.595 stopped after 17 iterations with relres 5.762e-09 after 0.357 seconds.
# Error Estimator: 0.0032
# setting up constraints took 0.14872527122497559 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.594 stopped after 17 iterations with relres 6.532e-09 after 0.546 seconds.
# Error Estimator: 0.00197
# setting up constraints took 0.17052865028381348 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.63 stopped after 17 iterations with relres 9.884e-09 after 0.521 seconds.
# Error Estimator: 0.00128
# setting up constraints took 0.19214940071105957 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.632 stopped after 18 iterations with relres 4.026e-09 after 0.585 seconds.
# Error Estimator: 0.000799
# setting up constraints took 0.2123699188232422 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.636 stopped after 18 iterations with relres 4.005e-09 after 0.65 seconds.
# Error Estimator: 0.000494
# setting up constraints took 0.24254822731018066 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.572 stopped after 18 iterations with relres 3.837e-09 after 0.755 seconds.
# Error Estimator: 0.000319
# setting up constraints took 0.26076579093933105 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.586 stopped after 18 iterations with relres 4.052e-09 after 0.814 seconds.
# Error Estimator: 0.0002
# setting up constraints took 0.2804391384124756 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.586 stopped after 18 iterations with relres 4.121e-09 after 0.934 seconds.
# Error Estimator: 0.000124
# setting up constraints took 0.30197906494140625 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.585 stopped after 18 iterations with relres 4.1e-09 after 1.03 seconds.
# Error Estimator: 8.02e-05
# setting up constraints took 0.32785630226135254 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.586 stopped after 18 iterations with relres 3.813e-09 after 1.12 seconds.
# Error Estimator: 5.07e-05
# setting up constraints took 0.3648858070373535 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.586 stopped after 18 iterations with relres 3.84e-09 after 1.2 seconds.
# Error Estimator: 3.21e-05
# setting up constraints took 0.36165475845336914 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.586 stopped after 18 iterations with relres 3.831e-09 after 1.29 seconds.
# Error Estimator: 2.18e-05
# setting up constraints took 0.4009683132171631 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.802 stopped after 18 iterations with relres 4.697e-09 after 1.37 seconds.
# Error Estimator: 1.42e-05
# setting up constraints took 0.43554210662841797 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 5.104 stopped after 18 iterations with relres 7.878e-09 after 1.47 seconds.
# Error Estimator: 9.05e-06
# setting up constraints took 0.46075892448425293 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 5.027 stopped after 19 iterations with relres 3.479e-09 after 1.83 seconds.
# Error Estimator: 5.63e-06
# setting up constraints took 0.5081644058227539 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 5.028 stopped after 19 iterations with relres 3.236e-09 after 1.94 seconds.
# Error Estimator: 3.33e-06
# setting up constraints took 0.560279130935669 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 5.028 stopped after 19 iterations with relres 3.303e-09 after 2.38 seconds.
# Error Estimator: 2.16e-06
# setting up constraints took 0.6203382015228271 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 5.048 stopped after 19 iterations with relres 4.516e-09 after 2.44 seconds.
# Error Estimator: 1.42e-06
# setting up constraints took 0.6727867126464844 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.978 stopped after 19 iterations with relres 3.691e-09 after 2.76 seconds.
# Error Estimator: 8.41e-07
# setting up constraints took 0.6748924255371094 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 4.977 stopped after 19 iterations with relres 3.785e-09 after 2.99 seconds.
# Error Estimator: 5.39e-07
# setting up constraints took 0.7309741973876953 seconds.
# #####################################################
# setting up constraints took 0.0016200542449951172 seconds.
# pcg with preconditioned condition number κ ~ 2.44 stopped after 7 iterations with relres 5.351e-10 after 0.0214 seconds.
# Error Estimator: 0.115
# setting up constraints took 0.012333393096923828 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 5.437 stopped after 17 iterations with relres 2.736e-09 after 0.11 seconds.
# Error Estimator: 0.0636
# setting up constraints took 0.026204824447631836 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.043 stopped after 20 iterations with relres 4.009e-09 after 0.27 seconds.
# Error Estimator: 0.0401
# setting up constraints took 0.0428922176361084 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.039 stopped after 20 iterations with relres 6.695e-09 after 0.424 seconds.
# Error Estimator: 0.0252
# setting up constraints took 0.05780625343322754 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.03 stopped after 20 iterations with relres 7.036e-09 after 0.595 seconds.
# Error Estimator: 0.0159
# setting up constraints took 0.0758969783782959 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.026 stopped after 20 iterations with relres 6.642e-09 after 0.715 seconds.
# Error Estimator: 0.01
# setting up constraints took 0.0948023796081543 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.024 stopped after 20 iterations with relres 6.827e-09 after 0.895 seconds.
# Error Estimator: 0.00632
# setting up constraints took 0.10919189453125 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.023 stopped after 20 iterations with relres 6.643e-09 after 1.14 seconds.
# Error Estimator: 0.00399
# setting up constraints took 0.1285409927368164 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.023 stopped after 20 iterations with relres 6.536e-09 after 1.25 seconds.
# Error Estimator: 0.00254
# setting up constraints took 0.15763139724731445 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.022 stopped after 20 iterations with relres 6.491e-09 after 1.35 seconds.
# Error Estimator: 0.00163
# setting up constraints took 0.17354774475097656 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.022 stopped after 20 iterations with relres 6.473e-09 after 1.48 seconds.
# Error Estimator: 0.00107
# setting up constraints took 0.181959867477417 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.021 stopped after 20 iterations with relres 6.464e-09 after 1.56 seconds.
# Error Estimator: 0.000747
# setting up constraints took 0.20776939392089844 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.019 stopped after 20 iterations with relres 7.996e-09 after 1.73 seconds.
# Error Estimator: 0.000462
# setting up constraints took 0.2395153045654297 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.144 stopped after 21 iterations with relres 3.898e-09 after 2.22 seconds.
# Error Estimator: 0.000298
# setting up constraints took 0.24918603897094727 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.285 stopped after 21 iterations with relres 4.795e-09 after 2.6 seconds.
# Error Estimator: 0.000187
# setting up constraints took 0.3075852394104004 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.288 stopped after 21 iterations with relres 5.07e-09 after 3.44 seconds.
# Error Estimator: 0.000115
# setting up constraints took 0.3053398132324219 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.288 stopped after 21 iterations with relres 4.557e-09 after 3.08 seconds.
# Error Estimator: 7.45e-05
# setting up constraints took 0.3293921947479248 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.242 stopped after 21 iterations with relres 4.592e-09 after 3.03 seconds.
# Error Estimator: 4.67e-05
# setting up constraints took 0.35529041290283203 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.242 stopped after 21 iterations with relres 4.688e-09 after 5.8 seconds.
# Error Estimator: 2.89e-05
# setting up constraints took 0.41077375411987305 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.242 stopped after 21 iterations with relres 4.677e-09 after 4.53 seconds.
# Error Estimator: 1.86e-05
# setting up constraints took 0.3991413116455078 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.24 stopped after 21 iterations with relres 4.655e-09 after 4.82 seconds.
# Error Estimator: 1.17e-05
# setting up constraints took 0.44208765029907227 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.24 stopped after 21 iterations with relres 4.663e-09 after 4.5 seconds.
# Error Estimator: 7.22e-06
# setting up constraints took 0.4510791301727295 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.24 stopped after 21 iterations with relres 4.667e-09 after 4.72 seconds.
# Error Estimator: 4.66e-06
# setting up constraints took 0.4715576171875 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.24 stopped after 21 iterations with relres 4.799e-09 after 4.71 seconds.
# Error Estimator: 2.92e-06
# setting up constraints took 0.6300296783447266 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.24 stopped after 21 iterations with relres 4.761e-09 after 4.99 seconds.
# Error Estimator: 1.8e-06
# setting up constraints took 0.5056278705596924 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.24 stopped after 21 iterations with relres 4.759e-09 after 5.33 seconds.
# Error Estimator: 1.17e-06
# setting up constraints took 0.5764086246490479 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.24 stopped after 21 iterations with relres 4.773e-09 after 5.73 seconds.
# Error Estimator: 7.31e-07
# setting up constraints took 0.5712175369262695 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.24 stopped after 21 iterations with relres 4.78e-09 after 8.36 seconds.
# Error Estimator: 4.52e-07
# setting up constraints took 0.5856540203094482 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.24 stopped after 21 iterations with relres 4.776e-09 after 9.07 seconds.
# Error Estimator: 2.93e-07
# setting up constraints took 0.6247482299804688 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.24 stopped after 21 iterations with relres 4.768e-09 after 11.3 seconds.
# Error Estimator: 1.86e-07
# setting up constraints took 0.6462476253509521 seconds.
# #####################################################
# pcg with preconditioned condition number κ ~ 6.24 stopped after 21 iterations with relres 4.769e-09 after 9.31 seconds.
# Error Estimator: 1.18e-07
# setting up constraints took 0.6657874584197998 seconds.
# #####################################################

# %%
R = np.load("LshapeQ_D_A.npy")
col=('royalblue','orange','green','red')
deg=(2,3,5,8)
for i in range(4):
    data = R[:,i*5+np.array([0,1,2])]
    rows_nonzero = np.any(data != 0, axis=1)

    if np.any(rows_nonzero):
        last = np.flatnonzero(rows_nonzero)[-1]
        data = data[:last + 1]
    else:
        data = data[:0]  # all rows are zero
    eta = data[:,0]
    it = data[:,1]
    kappa = data[:,2]
    #plt.semilogx(eta, it, "o-", color=col[i], markerfacecolor='none')
    plt.semilogx(eta, kappa, "o-", color=col[i], label="p="+str(deg[i]),markerfacecolor='none')
    plt.grid(True)
plt.ylabel("Condition number $\kappa$", size=10)
plt.xlabel("Error esimator $\eta$",size=10)
plt.gca().invert_xaxis()
plt.legend(loc='lower right')
plt.show()

# %%
RS = np.load("LshapeQ_S_B.npy")
RD = np.load("LshapeQ_D_B.npy")

# %%
R = np.zeros((31,21))
R[:,0]=np.arange(31)
R[:,np.array([1,2,3,6,7,8,11,12,13,16,17,18])]=RS[:,np.array([0,1,2,5,6,7,10,11,12,15,16,17])]
R[:,np.array([4,5,9,10,14,15,19,20])]=RD[:,np.array([1,2,6,7,11,12,16,17])]
np.savetxt('LshapeQ_B', R, fmt=('%d',)+len(degs)*('%1.1e','%d','%1.1f','%d','%1.1f'), delimiter = ' & ', newline='\\\\\n')

# %%
R
# Out:
# array([[0.00000e+00, 1.81772e-01, 4.00000e+00, 1.17642e+00, 4.00000e+00, 1.17709e+00, 1.33957e-01, 5.00000e+00, 1.41596e+00, 5.00000e+00, 1.41659e+00, 1.23937e-01, 6.00000e+00, 1.88065e+00, 6.00000e+00, 1.88124e+00, 1.15400e-01, 7.00000e+00, 2.43981e+00, 7.00000e+00, 2.44035e+00],
#        [1.00000e+00, 9.89401e-02, 1.10000e+01, 2.45420e+00, 9.00000e+00, 2.17944e+00, 7.31248e-02, 1.30000e+01, 3.00305e+00, 1.20000e+01, 2.65972e+00, 6.81749e-02, 1.50000e+01, 4.11569e+00, 1.40000e+01, 3.59441e+00, 6.35685e-02, 1.70000e+01, 5.43652e+00, 1.70000e+01, 4.94670e+00],
#        [2.00000e+00, 6.14843e-02, 1.20000e+01, 2.66855e+00, 1.10000e+01, 2.38613e+00, 4.65738e-02, 1.40000e+01, 3.40559e+00, 1.30000e+01, 2.87906e+00, 4.30382e-02, 1.70000e+01, 4.61345e+00, 1.60000e+01, 3.98488e+00, 4.00520e-02, 2.00000e+01, 6.04331e+00, 1.90000e+01, 5.39312e+00],
#        [3.00000e+00, 4.07207e-02, 1.30000e+01, 2.66568e+00, 1.20000e+01, 2.37069e+00, 3.01605e-02, 1.50000e+01, 3.40664e+00, 1.40000e+01, 2.84546e+00, 2.71606e-02, 1.70000e+01, 4.60789e+00, 1.70000e+01, 3.98447e+00, 2.52313e-02, 2.00000e+01, 6.03885e+00, 2.00000e+01, 5.53068e+00],
#        [4.00000e+00, 2.47956e-02, 1.30000e+01, 2.83235e+00, 1.20000e+01, 2.36573e+00, 2.00846e-02, 1.50000e+01, 3.40307e+00, 1.40000e+01, 2.86064e+00, 1.71638e-02, 1.70000e+01, 4.60085e+00, 1.70000e+01, 3.96956e+00, 1.58962e-02, 2.00000e+01, 6.03011e+00, 2.00000e+01, 5.53278e+00],
#        [5.00000e+00, 1.67344e-02, 1.40000e+01, 2.87069e+00, 1.20000e+01, 2.32649e+00, 1.41986e-02, 1.50000e+01, 3.40196e+00, 1.40000e+01, 2.84944e+00, 1.08948e-02, 1.70000e+01, 4.59748e+00, 1.70000e+01, 3.95711e+00, 1.00182e-02, 2.00000e+01, 6.02594e+00, 2.00000e+01, 5.50668e+00],
#        [6.00000e+00, 1.09356e-02, 1.40000e+01, 2.94426e+00, 1.20000e+01, 2.35529e+00, 8.76979e-03, 1.50000e+01, 3.40850e+00, 1.40000e+01, 2.81111e+00, 6.99258e-03, 1.70000e+01, 4.59603e+00, 1.70000e+01, 3.93143e+00, 6.31865e-03, 2.00000e+01, 6.02385e+00, 2.00000e+01, 5.48884e+00],
#        [7.00000e+00, 7.10992e-03, 1.40000e+01, 2.99569e+00, 1.20000e+01, 2.32670e+00, 5.73217e-03, 1.50000e+01, 3.46013e+00, 1.40000e+01, 2.76739e+00, 4.60438e-03, 1.70000e+01, 4.59533e+00, 1.70000e+01, 3.91781e+00, 3.99300e-03, 2.00000e+01, 6.02296e+00, 2.00000e+01, 5.48155e+00],
#        [8.00000e+00, 4.56452e-03, 1.40000e+01, 3.01811e+00, 1.20000e+01, 2.40387e+00, 3.59276e-03, 1.50000e+01, 3.45837e+00, 1.40000e+01, 2.83188e+00, 3.19543e-03, 1.70000e+01, 4.59496e+00, 1.70000e+01, 3.91312e+00, 2.53536e-03, 2.00000e+01, 6.02251e+00, 2.00000e+01, 5.47801e+00],
#        [9.00000e+00, 2.92035e-03, 1.50000e+01, 3.15320e+00, 1.20000e+01, 2.43480e+00, 2.26275e-03, 1.50000e+01, 3.45652e+00, 1.40000e+01, 2.87140e+00, 1.97462e-03, 1.70000e+01, 4.59389e+00, 1.70000e+01, 3.90828e+00, 1.62845e-03, 2.00000e+01, 6.02217e+00, 2.00000e+01, 5.47229e+00],
#        [1.00000e+01, 1.83992e-03, 1.50000e+01, 3.30645e+00, 1.20000e+01, 2.42037e+00, 1.53522e-03, 1.50000e+01, 3.43088e+00, 1.40000e+01, 2.87108e+00, 1.27568e-03, 1.70000e+01, 4.63015e+00, 1.70000e+01, 3.90839e+00, 1.07393e-03, 2.00000e+01, 6.02172e+00, 2.00000e+01, 5.46055e+00],
#        [1.10000e+01, 1.16871e-03, 1.50000e+01, 3.31824e+00, 1.30000e+01, 2.47440e+00, 9.66866e-04, 1.50000e+01, 3.38402e+00, 1.40000e+01, 2.93397e+00, 7.98790e-04, 1.80000e+01, 4.63160e+00, 1.70000e+01, 3.98150e+00, 7.47428e-04, 2.00000e+01, 6.02081e+00, 2.00000e+01, 5.44219e+00],
#        [1.20000e+01, 7.40271e-04, 1.50000e+01, 3.28907e+00, 1.30000e+01, 2.50352e+00, 6.17086e-04, 1.60000e+01, 3.58283e+00, 1.40000e+01, 2.91466e+00, 4.93936e-04, 1.80000e+01, 4.63612e+00, 1.70000e+01, 3.98749e+00, 4.61696e-04, 2.00000e+01, 6.01914e+00, 2.00000e+01, 5.43205e+00],
#        [1.30000e+01, 4.67754e-04, 1.50000e+01, 3.36121e+00, 1.30000e+01, 2.49518e+00, 3.97447e-04, 1.60000e+01, 3.78324e+00, 1.40000e+01, 2.90617e+00, 3.19115e-04, 1.80000e+01, 4.57211e+00, 1.70000e+01, 3.98746e+00, 2.98126e-04, 2.10000e+01, 6.14423e+00, 2.00000e+01, 5.42174e+00],
#        [1.40000e+01, 2.95552e-04, 1.50000e+01, 3.39270e+00, 1.30000e+01, 2.78209e+00, 2.43963e-04, 1.60000e+01, 3.66579e+00, 1.40000e+01, 2.92126e+00, 1.99866e-04, 1.80000e+01, 4.58639e+00, 1.70000e+01, 3.98532e+00, 1.86838e-04, 2.10000e+01, 6.28462e+00, 2.00000e+01, 5.56111e+00],
#        [1.50000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.55560e-04, 1.60000e+01, 3.69323e+00, 1.40000e+01, 2.91334e+00, 1.23805e-04, 1.80000e+01, 4.58646e+00, 1.70000e+01, 3.99137e+00, 1.15437e-04, 2.10000e+01, 6.28796e+00, 2.00000e+01, 5.56816e+00],
#        [1.60000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 9.97711e-05, 1.60000e+01, 3.85209e+00, 1.40000e+01, 2.92878e+00, 8.02453e-05, 1.80000e+01, 4.58541e+00, 1.70000e+01, 3.99289e+00, 7.45363e-05, 2.10000e+01, 6.28810e+00, 2.00000e+01, 5.56761e+00],
#        [1.70000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 6.33279e-05, 1.60000e+01, 3.81390e+00, 1.40000e+01, 3.00192e+00, 5.06906e-05, 1.80000e+01, 4.58619e+00, 1.70000e+01, 4.01814e+00, 4.67068e-05, 2.10000e+01, 6.24167e+00, 2.00000e+01, 5.66285e+00],
#        [1.80000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 3.96740e-05, 1.60000e+01, 4.03968e+00, 1.50000e+01, 3.05085e+00, 3.21128e-05, 1.80000e+01, 4.58611e+00, 1.70000e+01, 4.02048e+00, 2.88609e-05, 2.10000e+01, 6.24231e+00, 2.00000e+01, 5.67038e+00],
#        [1.90000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 2.51413e-05, 1.60000e+01, 4.03118e+00, 1.40000e+01, 3.02073e+00, 2.18073e-05, 1.80000e+01, 4.58609e+00, 1.70000e+01, 4.02045e+00, 1.86346e-05, 2.10000e+01, 6.24233e+00, 2.00000e+01, 5.67145e+00],
#        [2.00000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.58920e-05, 1.60000e+01, 4.10205e+00, 1.50000e+01, 3.01673e+00, 1.42142e-05, 1.80000e+01, 4.80202e+00, 1.70000e+01, 4.04013e+00, 1.16764e-05, 2.10000e+01, 6.24011e+00, 2.00000e+01, 5.72777e+00],
#        [2.10000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 9.91740e-06, 1.70000e+01, 4.04995e+00, 1.50000e+01, 3.08517e+00, 9.04674e-06, 1.80000e+01, 5.10435e+00, 1.70000e+01, 4.05116e+00, 7.21549e-06, 2.10000e+01, 6.24020e+00, 2.00000e+01, 5.72919e+00],
#        [2.20000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 6.30469e-06, 1.70000e+01, 4.12061e+00, 1.50000e+01, 3.08678e+00, 5.63225e-06, 1.90000e+01, 5.02706e+00, 1.70000e+01, 4.08822e+00, 4.65885e-06, 2.10000e+01, 6.24019e+00, 2.00000e+01, 5.72861e+00],
#        [2.30000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 3.33390e-06, 1.90000e+01, 5.02770e+00, 1.70000e+01, 4.11878e+00, 2.91927e-06, 2.10000e+01, 6.24005e+00, 2.00000e+01, 5.77451e+00],
#        [2.40000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 2.16325e-06, 1.90000e+01, 5.02765e+00, 1.70000e+01, 4.11331e+00, 1.80423e-06, 2.10000e+01, 6.24006e+00, 2.00000e+01, 5.77464e+00],
#        [2.50000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.41765e-06, 1.90000e+01, 5.04775e+00, 1.70000e+01, 4.12009e+00, 1.16524e-06, 2.10000e+01, 6.24007e+00, 2.00000e+01, 5.77443e+00],
#        [2.60000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 8.40820e-07, 1.90000e+01, 4.97761e+00, 1.70000e+01, 4.13469e+00, 7.30647e-07, 2.10000e+01, 6.24006e+00, 2.00000e+01, 5.80601e+00],
#        [2.70000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 5.38529e-07, 1.90000e+01, 4.97659e+00, 1.80000e+01, 4.14444e+00, 4.52410e-07, 2.10000e+01, 6.24005e+00, 2.00000e+01, 5.80602e+00],
#        [2.80000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 2.93396e-07, 2.10000e+01, 6.24005e+00, 2.00000e+01, 5.80599e+00],
#        [2.90000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.85967e-07, 2.10000e+01, 6.24006e+00, 2.10000e+01, 5.83199e+00],
#        [3.00000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.18368e-07, 2.10000e+01, 6.24006e+00, 2.10000e+01, 5.83199e+00]])

# %%
degs=(2,3,5,8)

# %%
RA = np.load("LshapeQ_S_A.npy")
RB = np.load("LshapeQ_S_B.npy")
col=('royalblue','orange','green','red')
for i in range(4):
    data1 = RA[:,i*5+np.array([0,3,4])]
    data2 = RB[:,i*5+np.array([0,3,4])]
    eta1=data1[:,0]
    eta2=data2[:,0]
    eta1=eta1[eta1!=0]
    eta2=eta2[eta2!=0]
    # Nprim = data[:,1]
    # eta=eta[eta!=0]
    # Nprim = Nprim[Nprim!=0]
    # Nprim=np.r_[0,Nprim]
    Npatches1 = data1[:,2]
    Npatches2 = data2[:,2]
    Npatches1 = Npatches1[Npatches1!=0]
    Npatches2 = Npatches2[Npatches2!=0]
    #plt.semilogx(eta,Nprim,"o-",color=col[i],markerfacecolor='none',label="$N_\pi$: p="+str(degs[i]))
    plt.semilogx(eta1,Npatches1,"o-",color=col[i],markerfacecolor='none',label="p="+str(degs[i])+", (A)")
    plt.semilogx(eta2,Npatches2,"s-",color=col[i],markerfacecolor='none',label="p="+str(degs[i])+", (B)")
plt.gca().invert_xaxis()
plt.legend(loc="upper left",fontsize=13)
plt.grid(True)
plt.tick_params(axis='both', labelsize=20)
plt.xlabel("Error estimator $\eta$", size=20)
plt.ylabel("Number of patches", size=20)
#plt.show()
plt.savefig('LshapeQ_Patches.pdf', bbox_inches='tight')

# %%
RA = np.load("LshapeQ_S_A.npy")
RB = np.load("LshapeQ_S_B.npy")
col=('royalblue','orange','green','red')
for i in range(4):
    data1 = RA[:,i*5+np.array([0,3,4])]
    data2 = RB[:,i*5+np.array([0,3,4])]
    eta1=data1[:,0]
    eta2=data2[:,0]
    eta1=eta1[eta1!=0]
    eta2=eta2[eta2!=0]
    # Nprim = data[:,1]
    # eta=eta[eta!=0]
    # Nprim = Nprim[Nprim!=0]
    # Nprim=np.r_[0,Nprim]
    Nprim1 = data1[:,1]
    Nprim2 = data2[:,1]
    Nprim1 = Nprim1[Nprim1!=0]
    Nprim2 = Nprim2[Nprim2!=0]
    Nprim1=np.r_[0,Nprim1]
    #plt.semilogx(eta,Nprim,"o-",color=col[i],markerfacecolor='none',label="$N_\pi$: p="+str(degs[i]))
    plt.semilogx(eta1,Nprim1,"o-",color=col[i],markerfacecolor='none',label="p="+str(degs[i])+", (A)")
    plt.semilogx(eta2,Nprim2,"s-",color=col[i],markerfacecolor='none',label="p="+str(degs[i])+", (B)")
plt.gca().invert_xaxis()
plt.legend(loc="upper left",fontsize=13)
plt.grid(True)
plt.tick_params(axis='both', labelsize=20)
plt.xlabel("Error estimator $\eta$", size=20)
plt.ylabel("Number of primals $N_\pi$", size=20)
#plt.show()
plt.savefig('LshapeQ_Patches.pdf', bbox_inches='tight')

# %%
R = np.load("LshapeS_B.npy")
for i in range(4):
    data = R[:,i*5+np.array([0,2])]
    rows_nonzero = np.any(data != 0, axis=1)

    if np.any(rows_nonzero):
        last = np.flatnonzero(rows_nonzero)[-1]
        data = data[:last + 1]
    else:
        data = data[:0]  # all rows are zero
    eta = data[:,0]
    it = data[:,1]
    plt.semilogx(eta,it)
plt.gca().invert_xaxis()
plt.show()

# %%
R = np.load("LshapeS_A.npy")

# %%
R.shape
# Out:
# (21, 21)

# %%
R=np.c_[np.arange(21),R]

# %%
np.savetxt('LshapeQ_S_A', R, fmt=('%d',)+len(degs)*('%1.2e','%d','%1.2f','%d','%d'), delimiter = ' & ', newline='\\\\\n')
